# %% [markdown]
# ## Imports

# %% [markdown]
# Libraries and device

# %%
# Standard imports
import numpy as np
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as T
import matplotlib.pyplot as plt
from tqdm import tqdm

from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score

import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# !pip install snntorch
import snntorch as snn
import snntorch.spikegen as spikegen
from snntorch import surrogate
from snntorch import utils
# from snntorch import spikegen

# In case you are fortunate enough to have access to a GPU...
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# Collecting snntorch
#   Downloading snntorch-0.9.4-py2.py3-none-any.whl.metadata (15 kB)
# Downloading snntorch-0.9.4-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.6/125.6 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: snntorch
# Successfully installed snntorch-0.9.4

# %% [markdown]
# ## Data

# %% [markdown]
# Import Data: Flattened MNIST

# %%
img_size = 28
ds = torchvision.datasets.MNIST('./files/', train=True, download=True,
                            transform=T.Compose([
                                T.Resize((img_size,img_size)),
                                T.ToTensor(),
                                T.Lambda((lambda x: torch.flatten(x))),
                            ]))
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 16.0MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 487kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.85MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.55MB/s]

# %% [markdown]
# Import Data: Flattened CIFAR-10

# %%
# img_size = 28

# ds = torchvision.datasets.CIFAR10(
#     './files/', train=False, download=True,
#     transform=T.Compose([
#         T.Resize((img_size, img_size)),     # Resize to 28x28
#         T.ToTensor(),                       # Convert to tensor
#         T.Lambda(lambda x: x.view(-1)),     # Flatten the image
#     ])
# )

# %% [markdown]
# Load pretrained MNIST Classifier

# %%
class MyNet(nn.Module):
    '''
     net = MyNet(img_size=28)

     Creates a neural network to do classification on MNIST.
     It assumes the images will be (img_size)x(img_size).

     The output of the network is the log of the 10 class probabilities
     (ie. log-softmax). Correspondingly, this network uses the
     negative log-likelihood loss function (nn.NLLLoss).
    '''
    def __init__(self, img_size=28):
        super().__init__()
        self.lyrs = nn.Sequential(
            nn.Linear(img_size**2, 100), nn.ReLU(),
            nn.Linear(100, 50), nn.ReLU(),
            nn.Linear(50, 10), nn.LogSoftmax(dim=-1),
            )
        self.loss_fcn = nn.NLLLoss()
        self.losses = []
        self.to(device)


    def forward(self, x):
        return self.lyrs(x)


    def learn(self, dl, optimizer=None, epochs=10):
        '''
         net.learn(dl, optimizer=None, epochs=10)

         Train the network on the dataset represented by the DataLoader dl.
         The default optimizer is Adam().

         The targets for the dataset are assumed to be class indices.
        '''
        if optimizer is None:
            print('Need to specify an optimizer and loss function')
            return

        for epoch in tqdm(range(epochs)):
            total_loss = 0.
            count = 0.
            for x, t in dl:
                x = x.to(device)   # for use with a GPU
                t = t.to(device)
                y = self(x)
                loss = self.loss_fcn(y, t)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.detach().numpy()
                count += 1.
            self.losses.append(total_loss/len(dl))
            #print(f'Epoch: {epoch}, loss: {total_loss/count}')
        plt.figure(figsize=(4,4))
        plt.plot(self.losses); plt.yscale('log');

net = torch.load('mnist_trained2.pt', weights_only=False).to(device)

# %% [markdown]
# Functions for adding noise to the MNIST data (noisier data will have a high classification difficulty score, which will be useful for curriculum learning training)

# %%
def add_noise_binary_flip(images, noise_level=0.2):
    noisy_images = images.clone()
    noise = torch.rand_like(noisy_images)
    flip_mask = noise < noise_level
    noisy_images[flip_mask] = 1 - noisy_images[flip_mask]
    return noisy_images

def add_noise_gaussian(images, std=0.2):
    noisy_images = images + torch.randn_like(images) * std
    noisy_images = torch.clamp(noisy_images, 0.0, 1.0)
    return noisy_images

def add_noise_salt_pepper(images, noise_level=0.2):
    noisy_images = images.clone()
    rand = torch.rand_like(noisy_images)
    noisy_images[rand < (noise_level / 2)] = 0.0    # Pepper
    noisy_images[(rand >= (noise_level / 2)) & (rand < noise_level)] = 1.0  # Salt
    return noisy_images

def add_noise_block(images, block_size=7, img_size=28):
    images = images.view(-1, 1, img_size, img_size).clone() # Unflatten images: [B, 784] → [B, 1, 28, 28]

    for img in images:
        x = torch.randint(0, img_size - block_size + 1, (1,))
        y = torch.randint(0, img_size - block_size + 1, (1,))
        img[:, y:y+block_size, x:x+block_size] = 0.0

    return images.view(-1, img_size * img_size) # Flatten back: [B, 1, 28, 28] → [B, 784]

# %% [markdown]
# Create datasets for curriculum learning

# %%
noise_levels = [0.0, 0.1, 0.2, 0.3, 0.4]

def create_noisy_datasets(func):
    def accuracy(net, dl):
        total_correct = 0.
        for x,t in dl:
            y = net(x.to(device))
            blah = torch.argmax(y.cpu(), dim=1)
            total_correct += torch.sum(blah==t).cpu().item()
        return total_correct/len(dl.dataset)

    dl = torch.utils.data.DataLoader(ds, batch_size=256)


    # block_sizes = [1, 3, 5, 7, 9]
    datasets = {}

    for noise_level in noise_levels:
        print(f'Noise level: {noise_level}')
        # Collect all images and labels with noise
        all_noisy_images = []
        all_labels = []


        for batch in dl:
            images, labels = batch
            noisy_images = func(images, noise_level)
            all_noisy_images.append(noisy_images)
            all_labels.append(labels)

        # Combine into one dataset
        all_noisy_images = torch.cat(all_noisy_images, dim=0)
        all_labels = torch.cat(all_labels, dim=0)

        # Create new dataloader with noisy images
        noisy_ds = torch.utils.data.TensorDataset(all_noisy_images, all_labels)
        noisy_dl = torch.utils.data.DataLoader(noisy_ds, batch_size=256, shuffle=False)

        datasets[noise_level] = noisy_ds

        # acc = accuracy(net, noisy_dl)
        # print(f'Accuracy = {acc*100.:0.2f}%')

    return datasets

print("Binary Flip Noise Dataset")
binary_flip_datasets = create_noisy_datasets(add_noise_binary_flip)
# print("Gaussian Noise Dataset")
# gaussian_datasets = create_noisy_datasets(add_noise_gaussian)
# print("Salt and Pepper Noise Dataset")
# salt_pepper_datasets = create_noisy_datasets(add_noise_salt_pepper)

# change noise levels
# train for more epochs
# plot loss and accuracy graphs
# repeat exp with diff types noise
# Out:
# Binary Flip Noise Dataset
# Noise level: 0.0
# Noise level: 0.1
# Noise level: 0.2
# Noise level: 0.3
# Noise level: 0.4

# %% [markdown]
# We can see that the pre-trained classifier performs worse when more noise is added to the data. In other words, noisier data is harder to classify. So by varying noise levels in MNIST, we've created a progressive difficulty spectrum which will be our curriculum.

# %%
# train_ds, test_ds = torch.utils.data.random_split(binary_flip_datasets[0.4], [0.2,0.8])

# total_len = len(binary_flip_datasets[0.4])
# #for 80%
# # train_len = int(0.2 * total_len)
# # test_len = total_len - train_len

# train_len = test_len = total_len // 2
# train_ds, test_ds = torch.utils.data.random_split(binary_flip_datasets[0.4], [train_len, test_len])


# combined_ds = torch.utils.data.ConcatDataset([binary_flip_datasets[noise_levels[0]], binary_flip_datasets[noise_levels[1]], binary_flip_datasets[noise_levels[2]], binary_flip_datasets[noise_levels[3]], train_ds])
# train_dl = DataLoader(combined_ds, batch_size=256, shuffle=True)
# test_dl = DataLoader(test_ds, batch_size=256)

#--- using some parts of all noise level data---
from torch.utils.data import random_split, ConcatDataset

# Split 0.4 noise data into train/test
# total_len = len(binary_flip_datasets[0.4])
# train_len = test_len = total_len // 2
# train_ds, test_ds_04 = random_split(binary_flip_datasets[0.4], [train_len, test_len])

# Sample 50% from each 0.0–0.3 dataset to use for testing
train_parts = []
test_parts = []
for nl in noise_levels:
    full_ds = binary_flip_datasets[nl]
    test_size = int(0.5 * len(full_ds))
    train_part, test_part = random_split(full_ds, [len(full_ds) - test_size, test_size])
    train_parts.append(train_part)
    test_parts.append(test_part)

# Combine all test subsets
test_ds = ConcatDataset(test_parts)
test_dl = DataLoader(test_ds, batch_size=256, shuffle=True)

# Combine training data from all levels, shuffle
combined_train_ds = ConcatDataset(train_parts)
combined_train_dl = DataLoader(combined_train_ds, batch_size=256, shuffle=True)

# %% [markdown]
# ## Train & Eval

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# Train function (also tracks accuracy)
def train_model(model, train_dl, test_dl, loss_fn, optimizer, epochs=10, patience=15, save_path="last_model.pth"):
    model.train()
    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    best_acc = 0.0
    early_stop_counter = 0

    for epoch in range(epochs):
        total_loss = 0
        all_preds = []
        all_labels = []

        for xb, yb in train_dl:
            xb = xb.to(device)
            yb = yb.to(device)

            pred = model(xb)
            loss = loss_fn(pred, yb)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            all_preds += pred.argmax(dim=1).tolist()
            all_labels += yb.tolist()

        avg_loss = total_loss / len(train_dl)
        acc = accuracy_score(all_labels, all_preds)
        train_losses.append(avg_loss)
        train_accuracies.append(acc)

        # Evaluate on test set
        test_loss, test_acc = evaluate_with_loss(model, test_dl, loss_fn)
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        print(f"Epoch {epoch+1}/{epochs}, "
              f"Train Loss: {avg_loss:.4f}, Train Acc: {acc:.4f}, "
              f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}")

        # Early stopping based on test accuracy
        if test_acc > best_acc:
            best_acc = test_acc
            early_stop_counter = 0
        else:
            early_stop_counter += 1
            if early_stop_counter >= patience:
                print(f"Early stopping at epoch {epoch+1} (no improvement in test accuracy for {patience} epochs)")
                break

    # Save the final model before stopping
    torch.save(model.state_dict(), save_path)
    print(f"Last model saved to {save_path}")

    return train_losses, train_accuracies, test_losses, test_accuracies

# Evaluate with loss and accuracy
def evaluate_with_loss(model, dataloader, loss_fn):
    model.eval()
    total_loss = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for xb, yb in dataloader:
            xb = xb.to(device)
            yb = yb.to(device)

            pred = model(xb)
            loss = loss_fn(pred, yb)

            total_loss += loss.item()
            all_preds += pred.argmax(dim=1).tolist()
            all_labels += yb.tolist()

    avg_loss = total_loss / len(dataloader)
    acc = accuracy_score(all_labels, all_preds)
    return avg_loss, acc

def plot_metrics(train_losses, test_losses, train_accs, test_accs,
                 epochs_per_level=None, stage_labels=None):
    import matplotlib.pyplot as plt

    epochs = list(range(1, len(train_losses) + 1))
    stage_boundaries = []
    if epochs_per_level:
        stage_boundaries = [sum(epochs_per_level[:i]) for i in range(1, len(epochs_per_level))]

    plt.figure(figsize=(12, 5))

    # --- Loss Plot ---
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', marker='o')
    plt.plot(epochs, test_losses, label='Test Loss', marker='o')

    for i, boundary in enumerate(stage_boundaries):
        plt.axvline(x=boundary, color='gray', linestyle='--')
        if stage_labels and i+1 < len(stage_labels):
            plt.text(boundary + 0.5, max(max(train_losses), max(test_losses)) * 0.9,
                     f"{stage_labels[i+1]}", rotation=90, va='top', ha='left', fontsize=9)

    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss over Epochs')
    plt.legend()
    plt.grid(True)

    # --- Accuracy Plot ---
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accs, label='Train Accuracy', marker='o')
    plt.plot(epochs, test_accs, label='Test Accuracy', marker='o')

    for i, boundary in enumerate(stage_boundaries):
        plt.axvline(x=boundary, color='gray', linestyle='--')
        if stage_labels and i+1 < len(stage_labels):
            plt.text(boundary + 0.5, max(max(train_accs), max(test_accs)) * 0.9,
                     f"{stage_labels[i+1]}", rotation=90, va='top', ha='left', fontsize=9)

    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Accuracy over Epochs')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Perceptron

# %% [markdown]
# Defining a Perceptron Model

# %%
# Define perceptron model
class Perceptron(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc = nn.Linear(784, 10)  # For MNIST: 28*28 = 784 inputs

    def forward(self, x):
        return self.fc(x)

# %% [markdown]
# Training using combined data (no curriculum)

# %%
# # Initialize
# model = Perceptron().to(device)
# loss_fn = nn.CrossEntropyLoss()
# optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# losses = train(model, combined_train_dl, loss_fn, optimizer, epochs=25)
# plot_training_loss(losses)
# evaluate(model, test_dl)

# Initialize
model = Perceptron().to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# Train and track metrics
train_losses, train_accs, test_losses, test_accs = train_model(
    model, combined_train_dl, test_dl, loss_fn, optimizer, epochs=25
)

# Plot
plot_metrics(train_losses, test_losses, train_accs, test_accs)
# Out:
# Epoch 1/25, Train Loss: 1.0415, Train Acc: 0.6921, Test Loss: 0.8512, Test Acc: 0.7324
# Epoch 2/25, Train Loss: 0.8174, Train Acc: 0.7397, Test Loss: 0.8157, Test Acc: 0.7372
# Epoch 3/25, Train Loss: 0.7938, Train Acc: 0.7442, Test Loss: 0.8099, Test Acc: 0.7370
# Epoch 4/25, Train Loss: 0.7850, Train Acc: 0.7458, Test Loss: 0.8072, Test Acc: 0.7387
# Epoch 5/25, Train Loss: 0.7806, Train Acc: 0.7462, Test Loss: 0.8063, Test Acc: 0.7386
# Epoch 6/25, Train Loss: 0.7787, Train Acc: 0.7473, Test Loss: 0.8107, Test Acc: 0.7364
# Epoch 7/25, Train Loss: 0.7769, Train Acc: 0.7475, Test Loss: 0.8111, Test Acc: 0.7374
# Epoch 8/25, Train Loss: 0.7762, Train Acc: 0.7481, Test Loss: 0.8090, Test Acc: 0.7372
# Epoch 9/25, Train Loss: 0.7756, Train Acc: 0.7478, Test Loss: 0.8105, Test Acc: 0.7372
# Epoch 10/25, Train Loss: 0.7747, Train Acc: 0.7486, Test Loss: 0.8116, Test Acc: 0.7368
# Epoch 11/25, Train Loss: 0.7745, Train Acc: 0.7478, Test Loss: 0.8091, Test Acc: 0.7381
# Epoch 12/25, Train Loss: 0.7738, Train Acc: 0.7483, Test Loss: 0.8124, Test Acc: 0.7370
# Epoch 13/25, Train Loss: 0.7734, Train Acc: 0.7484, Test Loss: 0.8090, Test Acc: 0.7380
# Epoch 14/25, Train Loss: 0.7736, Train Acc: 0.7478, Test Loss: 0.8119, Test Acc: 0.7365
# Epoch 15/25, Train Loss: 0.7731, Train Acc: 0.7482, Test Loss: 0.8124, Test Acc: 0.7367
# Epoch 16/25, Train Loss: 0.7729, Train Acc: 0.7487, Test Loss: 0.8100, Test Acc: 0.7370
# Epoch 17/25, Train Loss: 0.7726, Train Acc: 0.7487, Test Loss: 0.8095, Test Acc: 0.7373
# Epoch 18/25, Train Loss: 0.7721, Train Acc: 0.7484, Test Loss: 0.8088, Test Acc: 0.7381
# Epoch 19/25, Train Loss: 0.7720, Train Acc: 0.7492, Test Loss: 0.8100, Test Acc: 0.7370
# Epoch 20/25, Train Loss: 0.7718, Train Acc: 0.7491, Test Loss: 0.8155, Test Acc: 0.7362
# Epoch 21/25, Train Loss: 0.7721, Train Acc: 0.7487, Test Loss: 0.8118, Test Acc: 0.7371
# Epoch 22/25, Train Loss: 0.7716, Train Acc: 0.7493, Test Loss: 0.8085, Test Acc: 0.7381
# Epoch 23/25, Train Loss: 0.7718, Train Acc: 0.7493, Test Loss: 0.8121, Test Acc: 0.7367
# Epoch 24/25, Train Loss: 0.7717, Train Acc: 0.7486, Test Loss: 0.8102, Test Acc: 0.7371
# Epoch 25/25, Train Loss: 0.7715, Train Acc: 0.7492, Test Loss: 0.8095, Test Acc: 0.7375

# %% [markdown]
# Train using curriculum

# %%
# model2 = Perceptron().to(device)
# loss_fn = nn.CrossEntropyLoss().to(device)
# losses = np.array([])

# learning_rates = [0.06, 0.04, 0.03, 0.02, 0.01]
# epochs_per_level = [10,15,20,25,55]

# for i, noise_level in enumerate(noise_levels[:-1]):
#   train_dl = DataLoader(train_parts[i], batch_size=256, shuffle=True)
#   optimizer = torch.optim.SGD(model2.parameters(), lr=0.01, momentum=0.9)
#   losses = np.concatenate((losses, np.array(train(model2, train_dl, loss_fn, optimizer, epochs=epochs_per_level[i]))))

# plot_training_loss(losses)
# evaluate(model2, test_dl)

model2 = Perceptron().to(device)
loss_fn = nn.CrossEntropyLoss()

all_train_losses = []
all_test_losses = []
all_train_accuracies = []
all_test_accuracies = []

learning_rates = [0.06, 0.04, 0.03, 0.02, 0.01]
epochs_per_level = [10, 15, 20, 25, 55]

for i, noise_level in enumerate(noise_levels):
    train_dl = DataLoader(train_parts[i], batch_size=256, shuffle=True)
    optimizer = torch.optim.SGD(model2.parameters(), lr=0.01, momentum=0.9)

    train_losses, train_accs, test_losses, test_accs = train_model(
        model2, train_dl, test_dl, loss_fn, optimizer, epochs=epochs_per_level[i]
    )

    all_train_losses += train_losses
    all_test_losses += test_losses
    all_train_accuracies += train_accs
    all_test_accuracies += test_accs

plot_metrics(all_train_losses, all_test_losses, all_train_accuracies, all_test_accuracies)
# Out:
# Epoch 1/10, Train Loss: 0.9626, Train Acc: 0.7723, Test Loss: 1.2523, Test Acc: 0.6290
# Epoch 2/10, Train Loss: 0.5067, Train Acc: 0.8718, Test Loss: 1.2389, Test Acc: 0.6266
# Epoch 3/10, Train Loss: 0.4410, Train Acc: 0.8844, Test Loss: 1.2618, Test Acc: 0.6244
# Epoch 4/10, Train Loss: 0.4092, Train Acc: 0.8913, Test Loss: 1.2871, Test Acc: 0.6235
# Epoch 5/10, Train Loss: 0.3886, Train Acc: 0.8956, Test Loss: 1.3392, Test Acc: 0.6117
# Epoch 6/10, Train Loss: 0.3744, Train Acc: 0.8986, Test Loss: 1.3307, Test Acc: 0.6201
# Epoch 7/10, Train Loss: 0.3629, Train Acc: 0.9006, Test Loss: 1.3646, Test Acc: 0.6161
# Epoch 8/10, Train Loss: 0.3554, Train Acc: 0.9029, Test Loss: 1.4129, Test Acc: 0.6078
# Epoch 9/10, Train Loss: 0.3460, Train Acc: 0.9049, Test Loss: 1.4179, Test Acc: 0.6126
# Epoch 10/10, Train Loss: 0.3413, Train Acc: 0.9060, Test Loss: 1.4667, Test Acc: 0.6037
# Epoch 1/15, Train Loss: 0.4492, Train Acc: 0.8722, Test Loss: 1.0531, Test Acc: 0.6696
# Epoch 2/15, Train Loss: 0.4265, Train Acc: 0.8765, Test Loss: 1.0477, Test Acc: 0.6683
# Epoch 3/15, Train Loss: 0.4157, Train Acc: 0.8785, Test Loss: 1.1008, Test Acc: 0.6540
# Epoch 4/15, Train Loss: 0.4066, Train Acc: 0.8810, Test Loss: 1.0719, Test Acc: 0.6633
# Epoch 5/15, Train Loss: 0.3981, Train Acc: 0.8839, Test Loss: 1.1218, Test Acc: 0.6526
# Epoch 6/15, Train Loss: 0.3923, Train Acc: 0.8846, Test Loss: 1.1218, Test Acc: 0.6524
# Epoch 7/15, Train Loss: 0.3879, Train Acc: 0.8861, Test Loss: 1.1384, Test Acc: 0.6510
# Epoch 8/15, Train Loss: 0.3808, Train Acc: 0.8878, Test Loss: 1.1530, Test Acc: 0.6499
# Epoch 9/15, Train Loss: 0.3766, Train Acc: 0.8894, Test Loss: 1.1663, Test Acc: 0.6473
# Epoch 10/15, Train Loss: 0.3727, Train Acc: 0.8900, Test Loss: 1.1848, Test Acc: 0.6454
# Epoch 11/15, Train Loss: 0.3703, Train Acc: 0.8908, Test Loss: 1.2290, Test Acc: 0.6372
# Epoch 12/15, Train Loss: 0.3647, Train Acc: 0.8930, Test Loss: 1.1991, Test Acc: 0.6453
# Epoch 13/15, Train Loss: 0.3621, Train Acc: 0.8931, Test Loss: 1.2032, Test Acc: 0.6456
# Epoch 14/15, Train Loss: 0.3588, Train Acc: 0.8940, Test Loss: 1.2272, Test Acc: 0.6415
# Epoch 15/15, Train Loss: 0.3565, Train Acc: 0.8949, Test Loss: 1.2472, Test Acc: 0.6389
# Epoch 1/20, Train Loss: 0.6032, Train Acc: 0.8081, Test Loss: 0.9302, Test Acc: 0.7009
# Epoch 2/20, Train Loss: 0.5754, Train Acc: 0.8192, Test Loss: 0.9475, Test Acc: 0.6977
# Epoch 3/20, Train Loss: 0.5584, Train Acc: 0.8241, Test Loss: 0.9198, Test Acc: 0.7044
# Epoch 4/20, Train Loss: 0.5482, Train Acc: 0.8295, Test Loss: 0.9259, Test Acc: 0.7040
# Epoch 5/20, Train Loss: 0.5362, Train Acc: 0.8333, Test Loss: 0.9271, Test Acc: 0.7042
# Epoch 6/20, Train Loss: 0.5277, Train Acc: 0.8358, Test Loss: 0.9283, Test Acc: 0.7041
# Epoch 7/20, Train Loss: 0.5174, Train Acc: 0.8397, Test Loss: 0.9263, Test Acc: 0.7059
# Epoch 8/20, Train Loss: 0.5143, Train Acc: 0.8405, Test Loss: 0.9207, Test Acc: 0.7073
# Epoch 9/20, Train Loss: 0.5059, Train Acc: 0.8439, Test Loss: 0.9195, Test Acc: 0.7083
# Epoch 10/20, Train Loss: 0.5011, Train Acc: 0.8449, Test Loss: 0.9262, Test Acc: 0.7062
# Epoch 11/20, Train Loss: 0.4967, Train Acc: 0.8465, Test Loss: 0.9465, Test Acc: 0.7028
# Epoch 12/20, Train Loss: 0.4930, Train Acc: 0.8482, Test Loss: 0.9305, Test Acc: 0.7063
# Epoch 13/20, Train Loss: 0.4898, Train Acc: 0.8485, Test Loss: 0.9443, Test Acc: 0.7022
# Epoch 14/20, Train Loss: 0.4863, Train Acc: 0.8509, Test Loss: 0.9521, Test Acc: 0.7021
# Epoch 15/20, Train Loss: 0.4843, Train Acc: 0.8509, Test Loss: 0.9437, Test Acc: 0.7040
# Epoch 16/20, Train Loss: 0.4800, Train Acc: 0.8513, Test Loss: 0.9584, Test Acc: 0.7011
# Epoch 17/20, Train Loss: 0.4770, Train Acc: 0.8526, Test Loss: 0.9581, Test Acc: 0.7012
# Epoch 18/20, Train Loss: 0.4758, Train Acc: 0.8531, Test Loss: 0.9659, Test Acc: 0.7003
# Epoch 19/20, Train Loss: 0.4745, Train Acc: 0.8539, Test Loss: 0.9668, Test Acc: 0.7003
# Epoch 20/20, Train Loss: 0.4722, Train Acc: 0.8539, Test Loss: 0.9815, Test Acc: 0.6979
# Epoch 1/25, Train Loss: 0.9919, Train Acc: 0.6658, Test Loss: 0.9035, Test Acc: 0.7139
# Epoch 2/25, Train Loss: 0.9395, Train Acc: 0.6845, Test Loss: 0.8976, Test Acc: 0.7154
# Epoch 3/25, Train Loss: 0.9033, Train Acc: 0.6971, Test Loss: 0.8933, Test Acc: 0.7176
# Epoch 4/25, Train Loss: 0.8778, Train Acc: 0.7065, Test Loss: 0.8903, Test Acc: 0.7185
# Epoch 5/25, Train Loss: 0.8583, Train Acc: 0.7150, Test Loss: 0.8895, Test Acc: 0.7190
# Epoch 6/25, Train Loss: 0.8434, Train Acc: 0.7191, Test Loss: 0.8923, Test Acc: 0.7181
# Epoch 7/25, Train Loss: 0.8324, Train Acc: 0.7239, Test Loss: 0.8951, Test Acc: 0.7180
# Epoch 8/25, Train Loss: 0.8203, Train Acc: 0.7276, Test Loss: 0.8953, Test Acc: 0.7171
# Epoch 9/25, Train Loss: 0.8131, Train Acc: 0.7306, Test Loss: 0.8970, Test Acc: 0.7167
# Epoch 10/25, Train Loss: 0.8092, Train Acc: 0.7329, Test Loss: 0.9002, Test Acc: 0.7169
# Epoch 11/25, Train Loss: 0.8019, Train Acc: 0.7355, Test Loss: 0.9035, Test Acc: 0.7154
# Epoch 12/25, Train Loss: 0.7951, Train Acc: 0.7369, Test Loss: 0.9056, Test Acc: 0.7156
# Epoch 13/25, Train Loss: 0.7941, Train Acc: 0.7374, Test Loss: 0.9104, Test Acc: 0.7136
# Epoch 14/25, Train Loss: 0.7911, Train Acc: 0.7395, Test Loss: 0.9119, Test Acc: 0.7134
# Epoch 15/25, Train Loss: 0.7877, Train Acc: 0.7404, Test Loss: 0.9140, Test Acc: 0.7132
# Epoch 16/25, Train Loss: 0.7867, Train Acc: 0.7395, Test Loss: 0.9161, Test Acc: 0.7129
# Epoch 17/25, Train Loss: 0.7850, Train Acc: 0.7401, Test Loss: 0.9181, Test Acc: 0.7120
# Epoch 18/25, Train Loss: 0.7805, Train Acc: 0.7412, Test Loss: 0.9209, Test Acc: 0.7121
# Epoch 19/25, Train Loss: 0.7810, Train Acc: 0.7428, Test Loss: 0.9257, Test Acc: 0.7106
# Epoch 20/25, Train Loss: 0.7777, Train Acc: 0.7423, Test Loss: 0.9260, Test Acc: 0.7114
# Epoch 21/25, Train Loss: 0.7777, Train Acc: 0.7432, Test Loss: 0.9277, Test Acc: 0.7110
# Epoch 22/25, Train Loss: 0.7759, Train Acc: 0.7447, Test Loss: 0.9308, Test Acc: 0.7098
# Epoch 23/25, Train Loss: 0.7763, Train Acc: 0.7428, Test Loss: 0.9318, Test Acc: 0.7099
# Epoch 24/25, Train Loss: 0.7752, Train Acc: 0.7423, Test Loss: 0.9331, Test Acc: 0.7095
# Epoch 25/25, Train Loss: 0.7749, Train Acc: 0.7439, Test Loss: 0.9348, Test Acc: 0.7097
# Epoch 1/55, Train Loss: 1.8447, Train Acc: 0.4081, Test Loss: 0.9283, Test Acc: 0.7094
# Epoch 2/55, Train Loss: 1.7492, Train Acc: 0.4307, Test Loss: 0.9358, Test Acc: 0.7053
# Epoch 3/55, Train Loss: 1.6787, Train Acc: 0.4423, Test Loss: 0.9212, Test Acc: 0.7073
# Epoch 4/55, Train Loss: 1.6333, Train Acc: 0.4560, Test Loss: 0.9215, Test Acc: 0.7054
# Epoch 5/55, Train Loss: 1.5942, Train Acc: 0.4644, Test Loss: 0.9278, Test Acc: 0.7024
# Epoch 6/55, Train Loss: 1.5693, Train Acc: 0.4701, Test Loss: 0.9393, Test Acc: 0.6993
# Epoch 7/55, Train Loss: 1.5534, Train Acc: 0.4741, Test Loss: 0.9427, Test Acc: 0.6963
# Epoch 8/55, Train Loss: 1.5366, Train Acc: 0.4781, Test Loss: 0.9398, Test Acc: 0.6970
# Epoch 9/55, Train Loss: 1.5285, Train Acc: 0.4808, Test Loss: 0.9482, Test Acc: 0.6941
# Epoch 10/55, Train Loss: 1.5225, Train Acc: 0.4815, Test Loss: 0.9459, Test Acc: 0.6932
# Epoch 11/55, Train Loss: 1.5156, Train Acc: 0.4824, Test Loss: 0.9574, Test Acc: 0.6894
# Epoch 12/55, Train Loss: 1.5126, Train Acc: 0.4841, Test Loss: 0.9572, Test Acc: 0.6894
# Epoch 13/55, Train Loss: 1.5058, Train Acc: 0.4855, Test Loss: 0.9648, Test Acc: 0.6864
# Epoch 14/55, Train Loss: 1.5063, Train Acc: 0.4862, Test Loss: 0.9679, Test Acc: 0.6848
# Epoch 15/55, Train Loss: 1.5032, Train Acc: 0.4868, Test Loss: 0.9702, Test Acc: 0.6842
# Epoch 16/55, Train Loss: 1.5060, Train Acc: 0.4854, Test Loss: 0.9765, Test Acc: 0.6809
# Epoch 17/55, Train Loss: 1.4999, Train Acc: 0.4854, Test Loss: 0.9718, Test Acc: 0.6821
# Epoch 18/55, Train Loss: 1.5039, Train Acc: 0.4859, Test Loss: 0.9798, Test Acc: 0.6812
# Epoch 19/55, Train Loss: 1.4994, Train Acc: 0.4871, Test Loss: 0.9778, Test Acc: 0.6817
# Epoch 20/55, Train Loss: 1.5064, Train Acc: 0.4835, Test Loss: 0.9774, Test Acc: 0.6816
# Epoch 21/55, Train Loss: 1.5031, Train Acc: 0.4840, Test Loss: 0.9810, Test Acc: 0.6800
# Epoch 22/55, Train Loss: 1.5031, Train Acc: 0.4836, Test Loss: 0.9855, Test Acc: 0.6790
# Epoch 23/55, Train Loss: 1.4960, Train Acc: 0.4849, Test Loss: 0.9800, Test Acc: 0.6798
# Epoch 24/55, Train Loss: 1.4993, Train Acc: 0.4848, Test Loss: 0.9808, Test Acc: 0.6794
# Epoch 25/55, Train Loss: 1.4971, Train Acc: 0.4863, Test Loss: 0.9806, Test Acc: 0.6800
# Epoch 26/55, Train Loss: 1.5001, Train Acc: 0.4847, Test Loss: 0.9825, Test Acc: 0.6790
# Epoch 27/55, Train Loss: 1.5035, Train Acc: 0.4828, Test Loss: 0.9857, Test Acc: 0.6788
# Epoch 28/55, Train Loss: 1.4999, Train Acc: 0.4859, Test Loss: 0.9747, Test Acc: 0.6816
# Epoch 29/55, Train Loss: 1.4945, Train Acc: 0.4857, Test Loss: 0.9848, Test Acc: 0.6778
# Epoch 30/55, Train Loss: 1.4983, Train Acc: 0.4860, Test Loss: 0.9894, Test Acc: 0.6779
# Epoch 31/55, Train Loss: 1.4974, Train Acc: 0.4840, Test Loss: 0.9863, Test Acc: 0.6776
# Epoch 32/55, Train Loss: 1.4974, Train Acc: 0.4863, Test Loss: 0.9860, Test Acc: 0.6778
# Epoch 33/55, Train Loss: 1.4960, Train Acc: 0.4871, Test Loss: 0.9757, Test Acc: 0.6814
# Epoch 34/55, Train Loss: 1.4961, Train Acc: 0.4864, Test Loss: 0.9825, Test Acc: 0.6793
# Epoch 35/55, Train Loss: 1.4965, Train Acc: 0.4860, Test Loss: 0.9813, Test Acc: 0.6795
# Epoch 36/55, Train Loss: 1.4972, Train Acc: 0.4861, Test Loss: 0.9801, Test Acc: 0.6796
# Epoch 37/55, Train Loss: 1.4973, Train Acc: 0.4848, Test Loss: 0.9887, Test Acc: 0.6770
# Epoch 38/55, Train Loss: 1.4960, Train Acc: 0.4857, Test Loss: 0.9986, Test Acc: 0.6734
# Epoch 39/55, Train Loss: 1.4958, Train Acc: 0.4860, Test Loss: 0.9866, Test Acc: 0.6787
# Epoch 40/55, Train Loss: 1.4966, Train Acc: 0.4855, Test Loss: 0.9848, Test Acc: 0.6772
# Epoch 41/55, Train Loss: 1.4999, Train Acc: 0.4865, Test Loss: 0.9841, Test Acc: 0.6780
# Epoch 42/55, Train Loss: 1.4988, Train Acc: 0.4837, Test Loss: 0.9883, Test Acc: 0.6778
# Epoch 43/55, Train Loss: 1.4987, Train Acc: 0.4860, Test Loss: 0.9810, Test Acc: 0.6795
# Epoch 44/55, Train Loss: 1.4984, Train Acc: 0.4839, Test Loss: 0.9830, Test Acc: 0.6786
# Epoch 45/55, Train Loss: 1.4964, Train Acc: 0.4874, Test Loss: 0.9837, Test Acc: 0.6780
# Epoch 46/55, Train Loss: 1.4984, Train Acc: 0.4877, Test Loss: 0.9864, Test Acc: 0.6771
# Epoch 47/55, Train Loss: 1.4983, Train Acc: 0.4847, Test Loss: 0.9866, Test Acc: 0.6777
# Epoch 48/55, Train Loss: 1.4973, Train Acc: 0.4846, Test Loss: 0.9894, Test Acc: 0.6775
# Epoch 49/55, Train Loss: 1.4974, Train Acc: 0.4874, Test Loss: 0.9782, Test Acc: 0.6805
# Epoch 50/55, Train Loss: 1.4964, Train Acc: 0.4864, Test Loss: 0.9861, Test Acc: 0.6771
# Epoch 51/55, Train Loss: 1.4963, Train Acc: 0.4855, Test Loss: 0.9770, Test Acc: 0.6808
# Epoch 52/55, Train Loss: 1.4990, Train Acc: 0.4865, Test Loss: 0.9881, Test Acc: 0.6774
# Epoch 53/55, Train Loss: 1.4968, Train Acc: 0.4870, Test Loss: 0.9916, Test Acc: 0.6775
# Epoch 54/55, Train Loss: 1.4996, Train Acc: 0.4835, Test Loss: 0.9813, Test Acc: 0.6796
# Epoch 55/55, Train Loss: 1.4991, Train Acc: 0.4866, Test Loss: 0.9815, Test Acc: 0.6795

# %% [markdown]
# ## MLP (ReLU)

# %%
class MLP_ReLU(nn.Module):
    def __init__(self, input_dim=784, output_dim=10):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 1000), nn.ReLU(),
            nn.Linear(1000, 500), nn.ReLU(),
            nn.Linear(500, 50), nn.ReLU(),
            nn.Linear(50, output_dim), nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %%
loss_fn = nn.CrossEntropyLoss()
LEARNING_RATE = 0.03
EPOCHS = 100

# %%
mlp_relu_model = MLP_ReLU().to(device)
optimizer = torch.optim.SGD(mlp_relu_model.parameters(), lr=LEARNING_RATE, momentum=0.9)

# Use the new train function that also evaluates on test set
mlp_relu_train_losses, mlp_relu_train_accs, mlp_relu_test_losses, mlp_relu_test_accs = train_model(
    mlp_relu_model, combined_train_dl, test_dl, loss_fn, optimizer, epochs=EPOCHS, save_path = "mlp_relu_no_curriculum")

# Plot the losses and accuracies
plot_metrics(mlp_relu_train_losses, mlp_relu_test_losses, mlp_relu_train_accs, mlp_relu_test_accs)
# Out:
# Epoch 1/100, Train Loss: 1.2160, Train Acc: 0.5854, Test Loss: 0.7852, Test Acc: 0.7387
# Epoch 2/100, Train Loss: 0.6748, Train Acc: 0.7738, Test Loss: 0.6556, Test Acc: 0.7800
# Epoch 3/100, Train Loss: 0.5539, Train Acc: 0.8152, Test Loss: 0.6144, Test Acc: 0.7934
# Epoch 4/100, Train Loss: 0.4646, Train Acc: 0.8453, Test Loss: 0.6044, Test Acc: 0.7999
# Epoch 5/100, Train Loss: 0.3793, Train Acc: 0.8742, Test Loss: 0.6473, Test Acc: 0.7933
# Epoch 6/100, Train Loss: 0.3009, Train Acc: 0.8992, Test Loss: 0.6904, Test Acc: 0.7907
# Epoch 7/100, Train Loss: 0.2343, Train Acc: 0.9217, Test Loss: 0.7388, Test Acc: 0.7883
# Epoch 8/100, Train Loss: 0.1647, Train Acc: 0.9449, Test Loss: 0.8352, Test Acc: 0.7919
# Epoch 9/100, Train Loss: 0.1334, Train Acc: 0.9542, Test Loss: 0.8911, Test Acc: 0.7890
# Epoch 10/100, Train Loss: 0.0960, Train Acc: 0.9676, Test Loss: 0.9584, Test Acc: 0.7868
# Epoch 11/100, Train Loss: 0.0709, Train Acc: 0.9759, Test Loss: 1.1001, Test Acc: 0.7876
# Epoch 12/100, Train Loss: 0.0540, Train Acc: 0.9821, Test Loss: 1.1810, Test Acc: 0.7846
# Epoch 13/100, Train Loss: 0.0416, Train Acc: 0.9860, Test Loss: 1.2159, Test Acc: 0.7839
# Epoch 14/100, Train Loss: 0.0399, Train Acc: 0.9866, Test Loss: 1.2236, Test Acc: 0.7919
# Epoch 15/100, Train Loss: 0.0312, Train Acc: 0.9894, Test Loss: 1.2716, Test Acc: 0.7926
# Epoch 16/100, Train Loss: 0.0213, Train Acc: 0.9930, Test Loss: 1.3638, Test Acc: 0.7901
# Epoch 17/100, Train Loss: 0.0196, Train Acc: 0.9934, Test Loss: 1.4380, Test Acc: 0.7892
# Epoch 18/100, Train Loss: 0.0244, Train Acc: 0.9918, Test Loss: 1.3784, Test Acc: 0.7933
# Epoch 19/100, Train Loss: 0.0062, Train Acc: 0.9982, Test Loss: 1.5156, Test Acc: 0.7950
# Early stopping at epoch 19 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_relu_no_curriculum

# %%
mlp_relu_model_curriculum = MLP_ReLU().to(device)

# Accumulate metrics across curriculum levels
mlp_relu_all_train_losses = []
mlp_relu_all_test_losses = []
mlp_relu_all_train_accuracies = []
mlp_relu_all_test_accuracies = []

for i, noise_level in enumerate(noise_levels):
    train_dl = DataLoader(binary_flip_datasets[noise_level], batch_size=256, shuffle=True)
    optimizer = torch.optim.SGD(mlp_relu_model_curriculum.parameters(), lr=LEARNING_RATE, momentum=0.9)

    # Use new train function
    train_losses, train_accs, test_losses, test_accs = train_model(
        mlp_relu_model_curriculum, train_dl, test_dl, loss_fn, optimizer, epochs=EPOCHS, save_path = f"mlp_relu_forward_curriculum_{i+1}"
    )

    # Accumulate metrics
    mlp_relu_all_train_losses += train_losses
    mlp_relu_all_test_losses += test_losses
    mlp_relu_all_train_accuracies += train_accs
    mlp_relu_all_test_accuracies += test_accs
# Out:
# Epoch 1/100, Train Loss: 1.2536, Train Acc: 0.6045, Test Loss: 2.3700, Test Acc: 0.4676
# Epoch 2/100, Train Loss: 0.4733, Train Acc: 0.8291, Test Loss: 2.9213, Test Acc: 0.4525
# Epoch 3/100, Train Loss: 0.3872, Train Acc: 0.8534, Test Loss: 2.6631, Test Acc: 0.4940
# Epoch 4/100, Train Loss: 0.3509, Train Acc: 0.8623, Test Loss: 2.2255, Test Acc: 0.5194
# Epoch 5/100, Train Loss: 0.3267, Train Acc: 0.8695, Test Loss: 2.6422, Test Acc: 0.4918
# Epoch 6/100, Train Loss: 0.3123, Train Acc: 0.8732, Test Loss: 2.3702, Test Acc: 0.5136
# Epoch 7/100, Train Loss: 0.2991, Train Acc: 0.8769, Test Loss: 2.2954, Test Acc: 0.5241
# Epoch 8/100, Train Loss: 0.2902, Train Acc: 0.8798, Test Loss: 2.4515, Test Acc: 0.5117
# Epoch 9/100, Train Loss: 0.2835, Train Acc: 0.8813, Test Loss: 3.0036, Test Acc: 0.4897
# Epoch 10/100, Train Loss: 0.2771, Train Acc: 0.8833, Test Loss: 2.7211, Test Acc: 0.5118
# Epoch 11/100, Train Loss: 0.2236, Train Acc: 0.9073, Test Loss: 3.1993, Test Acc: 0.5273
# Epoch 12/100, Train Loss: 0.0163, Train Acc: 0.9959, Test Loss: 3.2055, Test Acc: 0.5362
# Epoch 13/100, Train Loss: 0.0120, Train Acc: 0.9972, Test Loss: 3.4237, Test Acc: 0.5358
# Epoch 14/100, Train Loss: 0.0091, Train Acc: 0.9980, Test Loss: 3.1176, Test Acc: 0.5593
# Epoch 15/100, Train Loss: 0.0057, Train Acc: 0.9991, Test Loss: 3.7522, Test Acc: 0.5354
# Epoch 16/100, Train Loss: 0.0042, Train Acc: 0.9993, Test Loss: 3.5249, Test Acc: 0.5516
# Epoch 17/100, Train Loss: 0.0030, Train Acc: 0.9996, Test Loss: 3.5995, Test Acc: 0.5547
# Epoch 18/100, Train Loss: 0.0027, Train Acc: 0.9997, Test Loss: 3.5983, Test Acc: 0.5540
# Epoch 19/100, Train Loss: 0.0023, Train Acc: 0.9998, Test Loss: 3.9469, Test Acc: 0.5425
# Epoch 20/100, Train Loss: 0.0019, Train Acc: 0.9998, Test Loss: 3.9537, Test Acc: 0.5463
# Epoch 21/100, Train Loss: 0.0017, Train Acc: 0.9998, Test Loss: 4.0123, Test Acc: 0.5460
# Epoch 22/100, Train Loss: 0.0015, Train Acc: 0.9998, Test Loss: 3.9976, Test Acc: 0.5490
# Epoch 23/100, Train Loss: 0.0015, Train Acc: 0.9998, Test Loss: 4.0310, Test Acc: 0.5487
# Epoch 24/100, Train Loss: 0.0014, Train Acc: 0.9998, Test Loss: 3.9398, Test Acc: 0.5539
# Epoch 25/100, Train Loss: 0.0013, Train Acc: 0.9998, Test Loss: 4.0586, Test Acc: 0.5497
# Epoch 26/100, Train Loss: 0.0012, Train Acc: 0.9998, Test Loss: 4.1524, Test Acc: 0.5484
# Epoch 27/100, Train Loss: 0.0011, Train Acc: 0.9998, Test Loss: 4.1118, Test Acc: 0.5499
# Epoch 28/100, Train Loss: 0.0011, Train Acc: 0.9998, Test Loss: 4.2357, Test Acc: 0.5453
# Epoch 29/100, Train Loss: 0.0011, Train Acc: 0.9998, Test Loss: 4.3928, Test Acc: 0.5397
# Early stopping at epoch 29 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_relu_forward_curriculum_1
# Epoch 1/100, Train Loss: 0.1808, Train Acc: 0.9430, Test Loss: 0.8888, Test Acc: 0.7202
# Epoch 2/100, Train Loss: 0.0517, Train Acc: 0.9841, Test Loss: 1.0448, Test Acc: 0.7089
# Epoch 3/100, Train Loss: 0.0159, Train Acc: 0.9962, Test Loss: 1.0479, Test Acc: 0.7300
# Epoch 4/100, Train Loss: 0.0057, Train Acc: 0.9992, Test Loss: 1.1292, Test Acc: 0.7278
# Epoch 5/100, Train Loss: 0.0029, Train Acc: 0.9997, Test Loss: 1.1510, Test Acc: 0.7324
# Epoch 6/100, Train Loss: 0.0020, Train Acc: 0.9998, Test Loss: 1.1942, Test Acc: 0.7312
# Epoch 7/100, Train Loss: 0.0017, Train Acc: 0.9998, Test Loss: 1.1494, Test Acc: 0.7381
# Epoch 8/100, Train Loss: 0.0013, Train Acc: 0.9998, Test Loss: 1.1651, Test Acc: 0.7385
# Epoch 9/100, Train Loss: 0.0010, Train Acc: 0.9999, Test Loss: 1.1960, Test Acc: 0.7387
# Epoch 10/100, Train Loss: 0.0009, Train Acc: 0.9999, Test Loss: 1.2708, Test Acc: 0.7329
# Epoch 11/100, Train Loss: 0.0008, Train Acc: 0.9999, Test Loss: 1.2322, Test Acc: 0.7378
# Epoch 12/100, Train Loss: 0.0008, Train Acc: 0.9999, Test Loss: 1.2261, Test Acc: 0.7392
# Epoch 13/100, Train Loss: 0.0007, Train Acc: 0.9999, Test Loss: 1.2576, Test Acc: 0.7375
# Epoch 14/100, Train Loss: 0.0006, Train Acc: 0.9999, Test Loss: 1.2681, Test Acc: 0.7375
# Epoch 15/100, Train Loss: 0.0006, Train Acc: 0.9999, Test Loss: 1.2562, Test Acc: 0.7389
# Epoch 16/100, Train Loss: 0.0006, Train Acc: 0.9999, Test Loss: 1.2883, Test Acc: 0.7364
# Epoch 17/100, Train Loss: 0.0006, Train Acc: 0.9999, Test Loss: 1.3037, Test Acc: 0.7360
# Epoch 18/100, Train Loss: 0.0005, Train Acc: 0.9999, Test Loss: 1.3118, Test Acc: 0.7356
# Epoch 19/100, Train Loss: 0.0004, Train Acc: 0.9999, Test Loss: 1.2742, Test Acc: 0.7396
# Epoch 20/100, Train Loss: 0.0004, Train Acc: 0.9999, Test Loss: 1.3514, Test Acc: 0.7344
# Epoch 21/100, Train Loss: 0.0004, Train Acc: 0.9999, Test Loss: 1.3164, Test Acc: 0.7376
# Epoch 22/100, Train Loss: 0.0004, Train Acc: 0.9999, Test Loss: 1.3575, Test Acc: 0.7353
# Epoch 23/100, Train Loss: 0.0004, Train Acc: 0.9999, Test Loss: 1.3359, Test Acc: 0.7372
# Epoch 24/100, Train Loss: 0.0004, Train Acc: 0.9999, Test Loss: 1.3447, Test Acc: 0.7370
# Epoch 25/100, Train Loss: 0.0004, Train Acc: 0.9999, Test Loss: 1.3633, Test Acc: 0.7362
# Epoch 26/100, Train Loss: 0.0004, Train Acc: 0.9999, Test Loss: 1.3765, Test Acc: 0.7358
# Epoch 27/100, Train Loss: 0.0003, Train Acc: 0.9999, Test Loss: 1.3640, Test Acc: 0.7369
# Epoch 28/100, Train Loss: 0.0003, Train Acc: 0.9999, Test Loss: 1.3649, Test Acc: 0.7377
# Epoch 29/100, Train Loss: 0.0003, Train Acc: 0.9999, Test Loss: 1.3654, Test Acc: 0.7376
# Epoch 30/100, Train Loss: 0.0003, Train Acc: 0.9999, Test Loss: 1.3799, Test Acc: 0.7371
# Epoch 31/100, Train Loss: 0.0003, Train Acc: 0.9999, Test Loss: 1.3862, Test Acc: 0.7367
# Epoch 32/100, Train Loss: 0.0003, Train Acc: 0.9999, Test Loss: 1.3928, Test Acc: 0.7369
# Epoch 33/100, Train Loss: 0.0003, Train Acc: 0.9999, Test Loss: 1.4129, Test Acc: 0.7354
# Epoch 34/100, Train Loss: 0.0003, Train Acc: 0.9999, Test Loss: 1.4046, Test Acc: 0.7364
# Early stopping at epoch 34 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_relu_forward_curriculum_2
# Epoch 1/100, Train Loss: 0.3971, Train Acc: 0.8751, Test Loss: 0.6510, Test Acc: 0.7848
# Epoch 2/100, Train Loss: 0.1651, Train Acc: 0.9472, Test Loss: 0.6965, Test Acc: 0.7829
# Epoch 3/100, Train Loss: 0.0720, Train Acc: 0.9792, Test Loss: 0.6925, Test Acc: 0.7942
# Epoch 4/100, Train Loss: 0.0283, Train Acc: 0.9931, Test Loss: 0.7334, Test Acc: 0.7961
# Epoch 5/100, Train Loss: 0.0097, Train Acc: 0.9988, Test Loss: 0.7915, Test Acc: 0.8015
# Epoch 6/100, Train Loss: 0.0050, Train Acc: 0.9993, Test Loss: 0.8444, Test Acc: 0.7979
# Epoch 7/100, Train Loss: 0.0037, Train Acc: 0.9995, Test Loss: 0.8522, Test Acc: 0.8017
# Epoch 8/100, Train Loss: 0.0030, Train Acc: 0.9996, Test Loss: 0.8513, Test Acc: 0.8012
# Epoch 9/100, Train Loss: 0.0022, Train Acc: 0.9996, Test Loss: 0.8499, Test Acc: 0.8031
# Epoch 10/100, Train Loss: 0.0019, Train Acc: 0.9997, Test Loss: 0.8733, Test Acc: 0.8028
# Epoch 11/100, Train Loss: 0.0015, Train Acc: 0.9997, Test Loss: 0.8859, Test Acc: 0.8024
# Epoch 12/100, Train Loss: 0.0017, Train Acc: 0.9998, Test Loss: 0.9160, Test Acc: 0.8020
# Epoch 13/100, Train Loss: 0.0013, Train Acc: 0.9998, Test Loss: 0.8954, Test Acc: 0.8024
# Epoch 14/100, Train Loss: 0.0011, Train Acc: 0.9998, Test Loss: 0.8998, Test Acc: 0.8039
# Epoch 15/100, Train Loss: 0.0009, Train Acc: 0.9998, Test Loss: 0.9024, Test Acc: 0.8039
# Epoch 16/100, Train Loss: 0.0008, Train Acc: 0.9998, Test Loss: 0.9153, Test Acc: 0.8037
# Epoch 17/100, Train Loss: 0.0009, Train Acc: 0.9998, Test Loss: 0.9181, Test Acc: 0.8042
# Epoch 18/100, Train Loss: 0.0009, Train Acc: 0.9998, Test Loss: 0.9126, Test Acc: 0.8045
# Epoch 19/100, Train Loss: 0.0008, Train Acc: 0.9998, Test Loss: 0.9345, Test Acc: 0.8025
# Epoch 20/100, Train Loss: 0.0007, Train Acc: 0.9998, Test Loss: 0.9205, Test Acc: 0.8034
# Epoch 21/100, Train Loss: 0.0007, Train Acc: 0.9998, Test Loss: 0.9329, Test Acc: 0.8037
# Epoch 22/100, Train Loss: 0.0007, Train Acc: 0.9998, Test Loss: 0.9385, Test Acc: 0.8030
# Epoch 23/100, Train Loss: 0.0006, Train Acc: 0.9998, Test Loss: 0.9540, Test Acc: 0.8031
# Epoch 24/100, Train Loss: 0.0006, Train Acc: 0.9998, Test Loss: 0.9367, Test Acc: 0.8043
# Epoch 25/100, Train Loss: 0.0006, Train Acc: 0.9998, Test Loss: 0.9483, Test Acc: 0.8040
# Epoch 26/100, Train Loss: 0.0005, Train Acc: 0.9998, Test Loss: 0.9511, Test Acc: 0.8040
# Epoch 27/100, Train Loss: 0.0005, Train Acc: 0.9998, Test Loss: 0.9593, Test Acc: 0.8040
# Epoch 28/100, Train Loss: 0.0005, Train Acc: 0.9998, Test Loss: 0.9691, Test Acc: 0.8035
# Epoch 29/100, Train Loss: 0.0005, Train Acc: 0.9998, Test Loss: 0.9653, Test Acc: 0.8043
# Epoch 30/100, Train Loss: 0.0005, Train Acc: 0.9998, Test Loss: 0.9688, Test Acc: 0.8043
# Epoch 31/100, Train Loss: 0.0005, Train Acc: 0.9998, Test Loss: 0.9732, Test Acc: 0.8045
# Epoch 32/100, Train Loss: 0.0005, Train Acc: 0.9998, Test Loss: 0.9761, Test Acc: 0.8043
# Epoch 33/100, Train Loss: 0.0005, Train Acc: 0.9998, Test Loss: 0.9824, Test Acc: 0.8042
# Early stopping at epoch 33 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_relu_forward_curriculum_3
# Epoch 1/100, Train Loss: 0.8872, Train Acc: 0.7189, Test Loss: 0.6114, Test Acc: 0.8070
# Epoch 2/100, Train Loss: 0.5702, Train Acc: 0.8122, Test Loss: 0.6011, Test Acc: 0.8189
# Epoch 3/100, Train Loss: 0.4224, Train Acc: 0.8599, Test Loss: 0.5903, Test Acc: 0.8281
# Epoch 4/100, Train Loss: 0.2977, Train Acc: 0.9022, Test Loss: 0.6307, Test Acc: 0.8302
# Epoch 5/100, Train Loss: 0.2006, Train Acc: 0.9348, Test Loss: 0.7437, Test Acc: 0.8273
# Epoch 6/100, Train Loss: 0.1398, Train Acc: 0.9553, Test Loss: 0.7685, Test Acc: 0.8362
# Epoch 7/100, Train Loss: 0.0947, Train Acc: 0.9700, Test Loss: 0.8138, Test Acc: 0.8363
# Epoch 8/100, Train Loss: 0.0745, Train Acc: 0.9764, Test Loss: 0.8648, Test Acc: 0.8395
# Epoch 9/100, Train Loss: 0.0459, Train Acc: 0.9867, Test Loss: 0.9319, Test Acc: 0.8400
# Epoch 10/100, Train Loss: 0.0380, Train Acc: 0.9891, Test Loss: 0.9781, Test Acc: 0.8409
# Epoch 11/100, Train Loss: 0.0212, Train Acc: 0.9944, Test Loss: 1.0066, Test Acc: 0.8423
# Epoch 12/100, Train Loss: 0.0171, Train Acc: 0.9957, Test Loss: 1.0369, Test Acc: 0.8400
# Epoch 13/100, Train Loss: 0.0117, Train Acc: 0.9972, Test Loss: 1.0269, Test Acc: 0.8446
# Epoch 14/100, Train Loss: 0.0065, Train Acc: 0.9987, Test Loss: 1.0641, Test Acc: 0.8436
# Epoch 15/100, Train Loss: 0.0047, Train Acc: 0.9989, Test Loss: 1.0647, Test Acc: 0.8459
# Epoch 16/100, Train Loss: 0.0040, Train Acc: 0.9990, Test Loss: 1.0667, Test Acc: 0.8462
# Epoch 17/100, Train Loss: 0.0036, Train Acc: 0.9990, Test Loss: 1.0493, Test Acc: 0.8469
# Epoch 18/100, Train Loss: 0.0033, Train Acc: 0.9990, Test Loss: 1.0703, Test Acc: 0.8462
# Epoch 19/100, Train Loss: 0.0030, Train Acc: 0.9991, Test Loss: 1.1015, Test Acc: 0.8457
# Epoch 20/100, Train Loss: 0.0029, Train Acc: 0.9991, Test Loss: 1.1072, Test Acc: 0.8461
# Epoch 21/100, Train Loss: 0.0028, Train Acc: 0.9992, Test Loss: 1.1024, Test Acc: 0.8469
# Epoch 22/100, Train Loss: 0.0025, Train Acc: 0.9992, Test Loss: 1.1066, Test Acc: 0.8469
# Epoch 23/100, Train Loss: 0.0025, Train Acc: 0.9992, Test Loss: 1.1168, Test Acc: 0.8472
# Epoch 24/100, Train Loss: 0.0024, Train Acc: 0.9992, Test Loss: 1.1408, Test Acc: 0.8472
# Epoch 25/100, Train Loss: 0.0024, Train Acc: 0.9992, Test Loss: 1.1447, Test Acc: 0.8472
# Epoch 26/100, Train Loss: 0.0024, Train Acc: 0.9992, Test Loss: 1.1536, Test Acc: 0.8470
# Epoch 27/100, Train Loss: 0.0023, Train Acc: 0.9992, Test Loss: 1.1648, Test Acc: 0.8471
# Epoch 28/100, Train Loss: 0.0023, Train Acc: 0.9992, Test Loss: 1.1634, Test Acc: 0.8470
# Epoch 29/100, Train Loss: 0.0022, Train Acc: 0.9992, Test Loss: 1.1715, Test Acc: 0.8471
# Epoch 30/100, Train Loss: 0.0022, Train Acc: 0.9992, Test Loss: 1.1816, Test Acc: 0.8471
# Epoch 31/100, Train Loss: 0.0022, Train Acc: 0.9992, Test Loss: 1.1862, Test Acc: 0.8470
# Epoch 32/100, Train Loss: 0.0022, Train Acc: 0.9992, Test Loss: 1.1959, Test Acc: 0.8469
# Epoch 33/100, Train Loss: 0.0022, Train Acc: 0.9992, Test Loss: 1.2006, Test Acc: 0.8470
# Epoch 34/100, Train Loss: 0.0022, Train Acc: 0.9992, Test Loss: 1.2071, Test Acc: 0.8470
# Epoch 35/100, Train Loss: 0.0023, Train Acc: 0.9992, Test Loss: 1.2117, Test Acc: 0.8467
# Epoch 36/100, Train Loss: 0.0022, Train Acc: 0.9992, Test Loss: 1.2172, Test Acc: 0.8469
# Epoch 37/100, Train Loss: 0.0022, Train Acc: 0.9992, Test Loss: 1.2201, Test Acc: 0.8469
# Epoch 38/100, Train Loss: 0.0022, Train Acc: 0.9992, Test Loss: 1.2255, Test Acc: 0.8470
# Epoch 39/100, Train Loss: 0.0022, Train Acc: 0.9992, Test Loss: 1.2292, Test Acc: 0.8471
# Early stopping at epoch 39 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_relu_forward_curriculum_4
# Epoch 1/100, Train Loss: 2.3437, Train Acc: 0.1050, Test Loss: 2.3978, Test Acc: 0.1580
# Epoch 2/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3978, Test Acc: 0.1580
# Epoch 3/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3978, Test Acc: 0.1580
# Epoch 4/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3978, Test Acc: 0.1580
# Epoch 5/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3978, Test Acc: 0.1580
# Epoch 6/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3979, Test Acc: 0.1580
# Epoch 7/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3978, Test Acc: 0.1580
# Epoch 8/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3978, Test Acc: 0.1580
# Epoch 9/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3978, Test Acc: 0.1580
# Epoch 10/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3978, Test Acc: 0.1580
# Epoch 11/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3978, Test Acc: 0.1580
# Epoch 12/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3978, Test Acc: 0.1580
# Epoch 13/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3978, Test Acc: 0.1580
# Epoch 14/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3978, Test Acc: 0.1580
# Epoch 15/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3978, Test Acc: 0.1580
# Epoch 16/100, Train Loss: 2.3026, Train Acc: 0.0987, Test Loss: 2.3978, Test Acc: 0.1580
# Early stopping at epoch 16 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_relu_forward_curriculum_5

# %%
# Plot the results
plot_metrics(mlp_relu_all_train_losses, mlp_relu_all_test_losses, mlp_relu_all_train_accuracies, mlp_relu_all_test_accuracies, epochs_per_level=[29,34,33,39,16], stage_labels=[f"Noise {nl}" for nl in noise_levels])

# %% [markdown]
# ## MLP (Sigmoid)

# %% [markdown]
# Defining MLP

# %%
class MLP_Sigmoid(nn.Module):
    def __init__(self, input_dim=784, output_dim=10):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 1000), nn.ReLU(),
            nn.Linear(1000, 500), nn.ReLU(),
            nn.Linear(500, 50), nn.ReLU(),
            nn.Linear(50, output_dim), nn.Sigmoid(), #nn.ReLU() nn.LogSoftmax(dim=-1)
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# Training a MLP (no curriculum)

# %%
loss_fn = nn.CrossEntropyLoss()
LEARNING_RATE = 0.03
EPOCHS = 100

# %%
mlp_sigmoid_model = MLP_Sigmoid().to(device)
optimizer = torch.optim.SGD(mlp_sigmoid_model.parameters(), lr=LEARNING_RATE, momentum=0.9)

# Use the new train function that also evaluates on test set
mlp_sigmoid_train_losses, mlp_sigmoid_train_accs, mlp_sigmoid_test_losses, mlp_sigmoid_test_accs = train_model(
    mlp_sigmoid_model, combined_train_dl, test_dl, loss_fn, optimizer, epochs=EPOCHS, save_path = "mlp_no_curriculum")

# Plot the losses and accuracies
plot_metrics(mlp_sigmoid_train_losses, mlp_sigmoid_test_losses, mlp_sigmoid_train_accs, mlp_sigmoid_test_accs)
# Out:
# Epoch 1/100, Train Loss: 2.0439, Train Acc: 0.3912, Test Loss: 1.8133, Test Acc: 0.5906
# Epoch 2/100, Train Loss: 1.7506, Train Acc: 0.6375, Test Loss: 1.7260, Test Acc: 0.6568
# Epoch 3/100, Train Loss: 1.7070, Train Acc: 0.6907, Test Loss: 1.7101, Test Acc: 0.6942
# Epoch 4/100, Train Loss: 1.6907, Train Acc: 0.7075, Test Loss: 1.7003, Test Acc: 0.7010
# Epoch 5/100, Train Loss: 1.6773, Train Acc: 0.7218, Test Loss: 1.6850, Test Acc: 0.7186
# Epoch 6/100, Train Loss: 1.6660, Train Acc: 0.7376, Test Loss: 1.6772, Test Acc: 0.7358
# Epoch 7/100, Train Loss: 1.6546, Train Acc: 0.7528, Test Loss: 1.6702, Test Acc: 0.7456
# Epoch 8/100, Train Loss: 1.6422, Train Acc: 0.7684, Test Loss: 1.6617, Test Acc: 0.7567
# Epoch 9/100, Train Loss: 1.6304, Train Acc: 0.7819, Test Loss: 1.6546, Test Acc: 0.7647
# Epoch 10/100, Train Loss: 1.6183, Train Acc: 0.7958, Test Loss: 1.6513, Test Acc: 0.7703
# Epoch 11/100, Train Loss: 1.6065, Train Acc: 0.8093, Test Loss: 1.6454, Test Acc: 0.7769
# Epoch 12/100, Train Loss: 1.5955, Train Acc: 0.8234, Test Loss: 1.6430, Test Acc: 0.7824
# Epoch 13/100, Train Loss: 1.5847, Train Acc: 0.8372, Test Loss: 1.6415, Test Acc: 0.7859
# Epoch 14/100, Train Loss: 1.5750, Train Acc: 0.8499, Test Loss: 1.6398, Test Acc: 0.7875
# Epoch 15/100, Train Loss: 1.5654, Train Acc: 0.8641, Test Loss: 1.6403, Test Acc: 0.7893
# Epoch 16/100, Train Loss: 1.5568, Train Acc: 0.8771, Test Loss: 1.6451, Test Acc: 0.7874
# Epoch 17/100, Train Loss: 1.5490, Train Acc: 0.8901, Test Loss: 1.6427, Test Acc: 0.7899
# Epoch 18/100, Train Loss: 1.5415, Train Acc: 0.9016, Test Loss: 1.6458, Test Acc: 0.7904
# Epoch 19/100, Train Loss: 1.5357, Train Acc: 0.9109, Test Loss: 1.6482, Test Acc: 0.7914
# Epoch 20/100, Train Loss: 1.5306, Train Acc: 0.9192, Test Loss: 1.6467, Test Acc: 0.7952
# Epoch 21/100, Train Loss: 1.5254, Train Acc: 0.9265, Test Loss: 1.6507, Test Acc: 0.7940
# Epoch 22/100, Train Loss: 1.5216, Train Acc: 0.9328, Test Loss: 1.6548, Test Acc: 0.7916
# Epoch 23/100, Train Loss: 1.5192, Train Acc: 0.9365, Test Loss: 1.6520, Test Acc: 0.7946
# Epoch 24/100, Train Loss: 1.5157, Train Acc: 0.9409, Test Loss: 1.6555, Test Acc: 0.7944
# Epoch 25/100, Train Loss: 1.5120, Train Acc: 0.9454, Test Loss: 1.6582, Test Acc: 0.7928
# Epoch 26/100, Train Loss: 1.5099, Train Acc: 0.9479, Test Loss: 1.6591, Test Acc: 0.7932
# Epoch 27/100, Train Loss: 1.5078, Train Acc: 0.9504, Test Loss: 1.6635, Test Acc: 0.7927
# Epoch 28/100, Train Loss: 1.5058, Train Acc: 0.9523, Test Loss: 1.6643, Test Acc: 0.7950
# Epoch 29/100, Train Loss: 1.5041, Train Acc: 0.9538, Test Loss: 1.6639, Test Acc: 0.7945
# Epoch 30/100, Train Loss: 1.5032, Train Acc: 0.9546, Test Loss: 1.6675, Test Acc: 0.7955
# Epoch 31/100, Train Loss: 1.5022, Train Acc: 0.9555, Test Loss: 1.6685, Test Acc: 0.7945
# Epoch 32/100, Train Loss: 1.5013, Train Acc: 0.9562, Test Loss: 1.6696, Test Acc: 0.7952
# Epoch 33/100, Train Loss: 1.5007, Train Acc: 0.9565, Test Loss: 1.6707, Test Acc: 0.7946
# Epoch 34/100, Train Loss: 1.5002, Train Acc: 0.9570, Test Loss: 1.6707, Test Acc: 0.7954
# Epoch 35/100, Train Loss: 1.4998, Train Acc: 0.9576, Test Loss: 1.6711, Test Acc: 0.7949
# Epoch 36/100, Train Loss: 1.4993, Train Acc: 0.9580, Test Loss: 1.6701, Test Acc: 0.7948
# Epoch 37/100, Train Loss: 1.4991, Train Acc: 0.9583, Test Loss: 1.6720, Test Acc: 0.7946
# Epoch 38/100, Train Loss: 1.4987, Train Acc: 0.9586, Test Loss: 1.6720, Test Acc: 0.7946
# Epoch 39/100, Train Loss: 1.4984, Train Acc: 0.9587, Test Loss: 1.6719, Test Acc: 0.7949
# Epoch 40/100, Train Loss: 1.4982, Train Acc: 0.9590, Test Loss: 1.6726, Test Acc: 0.7955
# Epoch 41/100, Train Loss: 1.4980, Train Acc: 0.9592, Test Loss: 1.6741, Test Acc: 0.7953
# Epoch 42/100, Train Loss: 1.4978, Train Acc: 0.9593, Test Loss: 1.6724, Test Acc: 0.7953
# Epoch 43/100, Train Loss: 1.4976, Train Acc: 0.9596, Test Loss: 1.6732, Test Acc: 0.7945
# Epoch 44/100, Train Loss: 1.4974, Train Acc: 0.9597, Test Loss: 1.6728, Test Acc: 0.7948
# Epoch 45/100, Train Loss: 1.4973, Train Acc: 0.9599, Test Loss: 1.6737, Test Acc: 0.7948
# Epoch 46/100, Train Loss: 1.4971, Train Acc: 0.9599, Test Loss: 1.6738, Test Acc: 0.7945
# Epoch 47/100, Train Loss: 1.4970, Train Acc: 0.9601, Test Loss: 1.6740, Test Acc: 0.7938
# Epoch 48/100, Train Loss: 1.4969, Train Acc: 0.9602, Test Loss: 1.6737, Test Acc: 0.7945
# Epoch 49/100, Train Loss: 1.4968, Train Acc: 0.9602, Test Loss: 1.6741, Test Acc: 0.7950
# Epoch 50/100, Train Loss: 1.4967, Train Acc: 0.9604, Test Loss: 1.6739, Test Acc: 0.7947
# Epoch 51/100, Train Loss: 1.4966, Train Acc: 0.9605, Test Loss: 1.6739, Test Acc: 0.7951
# Epoch 52/100, Train Loss: 1.4965, Train Acc: 0.9604, Test Loss: 1.6732, Test Acc: 0.7953
# Epoch 53/100, Train Loss: 1.4965, Train Acc: 0.9606, Test Loss: 1.6744, Test Acc: 0.7953
# Epoch 54/100, Train Loss: 1.4964, Train Acc: 0.9606, Test Loss: 1.6740, Test Acc: 0.7948
# Epoch 55/100, Train Loss: 1.4963, Train Acc: 0.9607, Test Loss: 1.6748, Test Acc: 0.7951
# Early stopping at epoch 55 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_no_curriculum

# %% [markdown]
# Training MLP (forward curriculum)

# %%
mlp_sigmoid_model_curriculum = MLP_Sigmoid().to(device)

# Accumulate metrics across curriculum levels
mlp_sigmoid_all_train_losses = []
mlp_sigmoid_all_test_losses = []
mlp_sigmoid_all_train_accuracies = []
mlp_sigmoid_all_test_accuracies = []

for i, noise_level in enumerate(noise_levels):
    train_dl = DataLoader(binary_flip_datasets[noise_level], batch_size=256, shuffle=True)
    optimizer = torch.optim.SGD(mlp_sigmoid_model_curriculum.parameters(), lr=LEARNING_RATE, momentum=0.9)

    # Use new train function
    train_losses, train_accs, test_losses, test_accs = train_model(
        mlp_sigmoid_model_curriculum, train_dl, test_dl, loss_fn, optimizer, epochs=EPOCHS, save_path = f"mlp_forward_curriculum_{i+1}"
    )

    # Accumulate metrics
    mlp_sigmoid_all_train_losses += train_losses
    mlp_sigmoid_all_test_losses += test_losses
    mlp_sigmoid_all_train_accuracies += train_accs
    mlp_sigmoid_all_test_accuracies += test_accs
# Out:
# Epoch 1/100, Train Loss: 2.1535, Train Acc: 0.4362, Test Loss: 2.0055, Test Acc: 0.3633
# Epoch 2/100, Train Loss: 1.6788, Train Acc: 0.6682, Test Loss: 1.9421, Test Acc: 0.4107
# Epoch 3/100, Train Loss: 1.6081, Train Acc: 0.7651, Test Loss: 1.9086, Test Acc: 0.4790
# Epoch 4/100, Train Loss: 1.5776, Train Acc: 0.8119, Test Loss: 1.9020, Test Acc: 0.4981
# Epoch 5/100, Train Loss: 1.5613, Train Acc: 0.8461, Test Loss: 1.9086, Test Acc: 0.5136
# Epoch 6/100, Train Loss: 1.5464, Train Acc: 0.9034, Test Loss: 1.9096, Test Acc: 0.5385
# Epoch 7/100, Train Loss: 1.5327, Train Acc: 0.9244, Test Loss: 1.9032, Test Acc: 0.5463
# Epoch 8/100, Train Loss: 1.5236, Train Acc: 0.9339, Test Loss: 1.9058, Test Acc: 0.5430
# Epoch 9/100, Train Loss: 1.5166, Train Acc: 0.9408, Test Loss: 1.9030, Test Acc: 0.5443
# Epoch 10/100, Train Loss: 1.5111, Train Acc: 0.9464, Test Loss: 1.8911, Test Acc: 0.5584
# Epoch 11/100, Train Loss: 1.5067, Train Acc: 0.9510, Test Loss: 1.9048, Test Acc: 0.5425
# Epoch 12/100, Train Loss: 1.5029, Train Acc: 0.9550, Test Loss: 1.9202, Test Acc: 0.5262
# Epoch 13/100, Train Loss: 1.4998, Train Acc: 0.9580, Test Loss: 1.9041, Test Acc: 0.5440
# Epoch 14/100, Train Loss: 1.4968, Train Acc: 0.9610, Test Loss: 1.9136, Test Acc: 0.5335
# Epoch 15/100, Train Loss: 1.4943, Train Acc: 0.9640, Test Loss: 1.9039, Test Acc: 0.5445
# Epoch 16/100, Train Loss: 1.4920, Train Acc: 0.9667, Test Loss: 1.9047, Test Acc: 0.5459
# Epoch 17/100, Train Loss: 1.4901, Train Acc: 0.9685, Test Loss: 1.9078, Test Acc: 0.5434
# Epoch 18/100, Train Loss: 1.4885, Train Acc: 0.9702, Test Loss: 1.9092, Test Acc: 0.5385
# Epoch 19/100, Train Loss: 1.4870, Train Acc: 0.9723, Test Loss: 1.9150, Test Acc: 0.5335
# Epoch 20/100, Train Loss: 1.4856, Train Acc: 0.9733, Test Loss: 1.9301, Test Acc: 0.5169
# Epoch 21/100, Train Loss: 1.4844, Train Acc: 0.9751, Test Loss: 1.9134, Test Acc: 0.5366
# Epoch 22/100, Train Loss: 1.4831, Train Acc: 0.9767, Test Loss: 1.9185, Test Acc: 0.5318
# Epoch 23/100, Train Loss: 1.4821, Train Acc: 0.9777, Test Loss: 1.9211, Test Acc: 0.5272
# Epoch 24/100, Train Loss: 1.4811, Train Acc: 0.9788, Test Loss: 1.9191, Test Acc: 0.5316
# Epoch 25/100, Train Loss: 1.4802, Train Acc: 0.9799, Test Loss: 1.9287, Test Acc: 0.5206
# Early stopping at epoch 25 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_forward_curriculum_1
# Epoch 1/100, Train Loss: 1.5225, Train Acc: 0.9315, Test Loss: 1.7645, Test Acc: 0.6766
# Epoch 2/100, Train Loss: 1.5044, Train Acc: 0.9518, Test Loss: 1.7435, Test Acc: 0.7021
# Epoch 3/100, Train Loss: 1.4965, Train Acc: 0.9608, Test Loss: 1.7530, Test Acc: 0.6929
# Epoch 4/100, Train Loss: 1.4914, Train Acc: 0.9670, Test Loss: 1.7505, Test Acc: 0.7012
# Epoch 5/100, Train Loss: 1.4875, Train Acc: 0.9713, Test Loss: 1.7533, Test Acc: 0.7002
# Epoch 6/100, Train Loss: 1.4845, Train Acc: 0.9753, Test Loss: 1.7540, Test Acc: 0.7043
# Epoch 7/100, Train Loss: 1.4822, Train Acc: 0.9781, Test Loss: 1.7602, Test Acc: 0.6984
# Epoch 8/100, Train Loss: 1.4804, Train Acc: 0.9796, Test Loss: 1.7574, Test Acc: 0.7032
# Epoch 9/100, Train Loss: 1.4790, Train Acc: 0.9813, Test Loss: 1.7692, Test Acc: 0.6882
# Epoch 10/100, Train Loss: 1.4779, Train Acc: 0.9827, Test Loss: 1.7650, Test Acc: 0.6977
# Epoch 11/100, Train Loss: 1.4770, Train Acc: 0.9837, Test Loss: 1.7648, Test Acc: 0.7000
# Epoch 12/100, Train Loss: 1.4761, Train Acc: 0.9845, Test Loss: 1.7687, Test Acc: 0.6957
# Epoch 13/100, Train Loss: 1.4756, Train Acc: 0.9850, Test Loss: 1.7705, Test Acc: 0.6963
# Epoch 14/100, Train Loss: 1.4750, Train Acc: 0.9856, Test Loss: 1.7758, Test Acc: 0.6899
# Epoch 15/100, Train Loss: 1.4746, Train Acc: 0.9860, Test Loss: 1.7721, Test Acc: 0.6968
# Epoch 16/100, Train Loss: 1.4741, Train Acc: 0.9866, Test Loss: 1.7743, Test Acc: 0.6940
# Epoch 17/100, Train Loss: 1.4738, Train Acc: 0.9867, Test Loss: 1.7724, Test Acc: 0.6967
# Epoch 18/100, Train Loss: 1.4735, Train Acc: 0.9869, Test Loss: 1.7726, Test Acc: 0.7001
# Epoch 19/100, Train Loss: 1.4732, Train Acc: 0.9872, Test Loss: 1.7777, Test Acc: 0.6926
# Epoch 20/100, Train Loss: 1.4729, Train Acc: 0.9873, Test Loss: 1.7793, Test Acc: 0.6904
# Epoch 21/100, Train Loss: 1.4728, Train Acc: 0.9877, Test Loss: 1.7771, Test Acc: 0.6934
# Early stopping at epoch 21 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_forward_curriculum_2
# Epoch 1/100, Train Loss: 1.5610, Train Acc: 0.8817, Test Loss: 1.6645, Test Acc: 0.7748
# Epoch 2/100, Train Loss: 1.5305, Train Acc: 0.9187, Test Loss: 1.6555, Test Acc: 0.7885
# Epoch 3/100, Train Loss: 1.5157, Train Acc: 0.9361, Test Loss: 1.6587, Test Acc: 0.7885
# Epoch 4/100, Train Loss: 1.5058, Train Acc: 0.9501, Test Loss: 1.6624, Test Acc: 0.7895
# Epoch 5/100, Train Loss: 1.4989, Train Acc: 0.9587, Test Loss: 1.6625, Test Acc: 0.7923
# Epoch 6/100, Train Loss: 1.4935, Train Acc: 0.9653, Test Loss: 1.6641, Test Acc: 0.7942
# Epoch 7/100, Train Loss: 1.4897, Train Acc: 0.9696, Test Loss: 1.6696, Test Acc: 0.7903
# Epoch 8/100, Train Loss: 1.4873, Train Acc: 0.9724, Test Loss: 1.6695, Test Acc: 0.7949
# Epoch 9/100, Train Loss: 1.4854, Train Acc: 0.9743, Test Loss: 1.6713, Test Acc: 0.7945
# Epoch 10/100, Train Loss: 1.4842, Train Acc: 0.9754, Test Loss: 1.6743, Test Acc: 0.7934
# Epoch 11/100, Train Loss: 1.4831, Train Acc: 0.9764, Test Loss: 1.6744, Test Acc: 0.7945
# Epoch 12/100, Train Loss: 1.4824, Train Acc: 0.9769, Test Loss: 1.6775, Test Acc: 0.7900
# Epoch 13/100, Train Loss: 1.4819, Train Acc: 0.9773, Test Loss: 1.6772, Test Acc: 0.7919
# Epoch 14/100, Train Loss: 1.4814, Train Acc: 0.9777, Test Loss: 1.6762, Test Acc: 0.7935
# Epoch 15/100, Train Loss: 1.4811, Train Acc: 0.9781, Test Loss: 1.6780, Test Acc: 0.7916
# Epoch 16/100, Train Loss: 1.4808, Train Acc: 0.9783, Test Loss: 1.6791, Test Acc: 0.7907
# Epoch 17/100, Train Loss: 1.4805, Train Acc: 0.9786, Test Loss: 1.6784, Test Acc: 0.7921
# Epoch 18/100, Train Loss: 1.4802, Train Acc: 0.9787, Test Loss: 1.6788, Test Acc: 0.7912
# Epoch 19/100, Train Loss: 1.4800, Train Acc: 0.9790, Test Loss: 1.6791, Test Acc: 0.7922
# Epoch 20/100, Train Loss: 1.4798, Train Acc: 0.9792, Test Loss: 1.6785, Test Acc: 0.7924
# Epoch 21/100, Train Loss: 1.4796, Train Acc: 0.9794, Test Loss: 1.6792, Test Acc: 0.7925
# Epoch 22/100, Train Loss: 1.4795, Train Acc: 0.9795, Test Loss: 1.6794, Test Acc: 0.7915
# Epoch 23/100, Train Loss: 1.4794, Train Acc: 0.9796, Test Loss: 1.6802, Test Acc: 0.7910
# Early stopping at epoch 23 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_forward_curriculum_3
# Epoch 1/100, Train Loss: 1.6848, Train Acc: 0.7275, Test Loss: 1.6326, Test Acc: 0.8034
# Epoch 2/100, Train Loss: 1.6335, Train Acc: 0.7835, Test Loss: 1.6241, Test Acc: 0.8121
# Epoch 3/100, Train Loss: 1.6051, Train Acc: 0.8175, Test Loss: 1.6183, Test Acc: 0.8184
# Epoch 4/100, Train Loss: 1.5811, Train Acc: 0.8492, Test Loss: 1.6155, Test Acc: 0.8227
# Epoch 5/100, Train Loss: 1.5622, Train Acc: 0.8743, Test Loss: 1.6150, Test Acc: 0.8260
# Epoch 6/100, Train Loss: 1.5482, Train Acc: 0.8946, Test Loss: 1.6128, Test Acc: 0.8320
# Epoch 7/100, Train Loss: 1.5361, Train Acc: 0.9139, Test Loss: 1.6127, Test Acc: 0.8342
# Epoch 8/100, Train Loss: 1.5270, Train Acc: 0.9265, Test Loss: 1.6137, Test Acc: 0.8361
# Epoch 9/100, Train Loss: 1.5206, Train Acc: 0.9349, Test Loss: 1.6128, Test Acc: 0.8383
# Epoch 10/100, Train Loss: 1.5147, Train Acc: 0.9427, Test Loss: 1.6146, Test Acc: 0.8390
# Epoch 11/100, Train Loss: 1.5109, Train Acc: 0.9474, Test Loss: 1.6171, Test Acc: 0.8390
# Epoch 12/100, Train Loss: 1.5084, Train Acc: 0.9496, Test Loss: 1.6168, Test Acc: 0.8405
# Epoch 13/100, Train Loss: 1.5067, Train Acc: 0.9513, Test Loss: 1.6177, Test Acc: 0.8402
# Epoch 14/100, Train Loss: 1.5055, Train Acc: 0.9524, Test Loss: 1.6189, Test Acc: 0.8402
# Epoch 15/100, Train Loss: 1.5046, Train Acc: 0.9532, Test Loss: 1.6195, Test Acc: 0.8401
# Epoch 16/100, Train Loss: 1.5040, Train Acc: 0.9537, Test Loss: 1.6191, Test Acc: 0.8409
# Epoch 17/100, Train Loss: 1.5034, Train Acc: 0.9546, Test Loss: 1.6197, Test Acc: 0.8400
# Epoch 18/100, Train Loss: 1.5030, Train Acc: 0.9548, Test Loss: 1.6197, Test Acc: 0.8406
# Epoch 19/100, Train Loss: 1.5026, Train Acc: 0.9551, Test Loss: 1.6199, Test Acc: 0.8404
# Epoch 20/100, Train Loss: 1.5022, Train Acc: 0.9553, Test Loss: 1.6196, Test Acc: 0.8407
# Epoch 21/100, Train Loss: 1.5020, Train Acc: 0.9556, Test Loss: 1.6202, Test Acc: 0.8407
# Epoch 22/100, Train Loss: 1.5018, Train Acc: 0.9557, Test Loss: 1.6201, Test Acc: 0.8405
# Epoch 23/100, Train Loss: 1.5016, Train Acc: 0.9559, Test Loss: 1.6202, Test Acc: 0.8403
# Epoch 24/100, Train Loss: 1.5012, Train Acc: 0.9561, Test Loss: 1.6203, Test Acc: 0.8404
# Epoch 25/100, Train Loss: 1.5010, Train Acc: 0.9563, Test Loss: 1.6203, Test Acc: 0.8404
# Epoch 26/100, Train Loss: 1.5009, Train Acc: 0.9563, Test Loss: 1.6206, Test Acc: 0.8403
# Epoch 27/100, Train Loss: 1.5009, Train Acc: 0.9565, Test Loss: 1.6211, Test Acc: 0.8401
# Epoch 28/100, Train Loss: 1.5007, Train Acc: 0.9565, Test Loss: 1.6213, Test Acc: 0.8400
# Epoch 29/100, Train Loss: 1.5005, Train Acc: 0.9566, Test Loss: 1.6209, Test Acc: 0.8402
# Epoch 30/100, Train Loss: 1.5004, Train Acc: 0.9568, Test Loss: 1.6212, Test Acc: 0.8403
# Epoch 31/100, Train Loss: 1.5003, Train Acc: 0.9569, Test Loss: 1.6216, Test Acc: 0.8399
# Early stopping at epoch 31 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_forward_curriculum_4
# Epoch 1/100, Train Loss: 2.0140, Train Acc: 0.3806, Test Loss: 1.6701, Test Acc: 0.7562
# Epoch 2/100, Train Loss: 1.9480, Train Acc: 0.4307, Test Loss: 1.6474, Test Acc: 0.7717
# Epoch 3/100, Train Loss: 1.9129, Train Acc: 0.4618, Test Loss: 1.6445, Test Acc: 0.7772
# Epoch 4/100, Train Loss: 1.8820, Train Acc: 0.4849, Test Loss: 1.6321, Test Acc: 0.7800
# Epoch 5/100, Train Loss: 1.8556, Train Acc: 0.5090, Test Loss: 1.6299, Test Acc: 0.7779
# Epoch 6/100, Train Loss: 1.8278, Train Acc: 0.5372, Test Loss: 1.6155, Test Acc: 0.7939
# Epoch 7/100, Train Loss: 1.7994, Train Acc: 0.5677, Test Loss: 1.6068, Test Acc: 0.8027
# Epoch 8/100, Train Loss: 1.7714, Train Acc: 0.6023, Test Loss: 1.5996, Test Acc: 0.8168
# Epoch 9/100, Train Loss: 1.7448, Train Acc: 0.6371, Test Loss: 1.5897, Test Acc: 0.8290
# Epoch 10/100, Train Loss: 1.7227, Train Acc: 0.6711, Test Loss: 1.5867, Test Acc: 0.8343
# Epoch 11/100, Train Loss: 1.6993, Train Acc: 0.7064, Test Loss: 1.5786, Test Acc: 0.8471
# Epoch 12/100, Train Loss: 1.6792, Train Acc: 0.7393, Test Loss: 1.5777, Test Acc: 0.8477
# Epoch 13/100, Train Loss: 1.6650, Train Acc: 0.7629, Test Loss: 1.5734, Test Acc: 0.8550
# Epoch 14/100, Train Loss: 1.6493, Train Acc: 0.7866, Test Loss: 1.5706, Test Acc: 0.8640
# Epoch 15/100, Train Loss: 1.6369, Train Acc: 0.8069, Test Loss: 1.5688, Test Acc: 0.8671
# Epoch 16/100, Train Loss: 1.6254, Train Acc: 0.8232, Test Loss: 1.5679, Test Acc: 0.8716
# Epoch 17/100, Train Loss: 1.6171, Train Acc: 0.8352, Test Loss: 1.5658, Test Acc: 0.8752
# Epoch 18/100, Train Loss: 1.6084, Train Acc: 0.8458, Test Loss: 1.5654, Test Acc: 0.8771
# Epoch 19/100, Train Loss: 1.6015, Train Acc: 0.8538, Test Loss: 1.5653, Test Acc: 0.8790
# Epoch 20/100, Train Loss: 1.5982, Train Acc: 0.8576, Test Loss: 1.5679, Test Acc: 0.8777
# Epoch 21/100, Train Loss: 1.5928, Train Acc: 0.8614, Test Loss: 1.5667, Test Acc: 0.8810
# Epoch 22/100, Train Loss: 1.5902, Train Acc: 0.8641, Test Loss: 1.5669, Test Acc: 0.8818
# Epoch 23/100, Train Loss: 1.5880, Train Acc: 0.8652, Test Loss: 1.5662, Test Acc: 0.8829
# Epoch 24/100, Train Loss: 1.5862, Train Acc: 0.8664, Test Loss: 1.5675, Test Acc: 0.8824
# Epoch 25/100, Train Loss: 1.5851, Train Acc: 0.8670, Test Loss: 1.5672, Test Acc: 0.8830
# Epoch 26/100, Train Loss: 1.5841, Train Acc: 0.8674, Test Loss: 1.5672, Test Acc: 0.8829
# Epoch 27/100, Train Loss: 1.5834, Train Acc: 0.8679, Test Loss: 1.5674, Test Acc: 0.8832
# Epoch 28/100, Train Loss: 1.5830, Train Acc: 0.8683, Test Loss: 1.5674, Test Acc: 0.8833
# Epoch 29/100, Train Loss: 1.5825, Train Acc: 0.8683, Test Loss: 1.5682, Test Acc: 0.8823
# Epoch 30/100, Train Loss: 1.5821, Train Acc: 0.8683, Test Loss: 1.5675, Test Acc: 0.8830
# Epoch 31/100, Train Loss: 1.5817, Train Acc: 0.8685, Test Loss: 1.5677, Test Acc: 0.8825
# Epoch 32/100, Train Loss: 1.5813, Train Acc: 0.8686, Test Loss: 1.5673, Test Acc: 0.8833
# Epoch 33/100, Train Loss: 1.5812, Train Acc: 0.8688, Test Loss: 1.5678, Test Acc: 0.8826
# Epoch 34/100, Train Loss: 1.5812, Train Acc: 0.8691, Test Loss: 1.5676, Test Acc: 0.8828
# Epoch 35/100, Train Loss: 1.5806, Train Acc: 0.8691, Test Loss: 1.5675, Test Acc: 0.8828
# Epoch 36/100, Train Loss: 1.5805, Train Acc: 0.8693, Test Loss: 1.5674, Test Acc: 0.8829
# Epoch 37/100, Train Loss: 1.5804, Train Acc: 0.8693, Test Loss: 1.5673, Test Acc: 0.8831
# Epoch 38/100, Train Loss: 1.5802, Train Acc: 0.8693, Test Loss: 1.5688, Test Acc: 0.8816
# Epoch 39/100, Train Loss: 1.5802, Train Acc: 0.8693, Test Loss: 1.5675, Test Acc: 0.8826
# Epoch 40/100, Train Loss: 1.5799, Train Acc: 0.8694, Test Loss: 1.5671, Test Acc: 0.8828
# Epoch 41/100, Train Loss: 1.5798, Train Acc: 0.8696, Test Loss: 1.5673, Test Acc: 0.8826
# Epoch 42/100, Train Loss: 1.5799, Train Acc: 0.8697, Test Loss: 1.5671, Test Acc: 0.8828
# Epoch 43/100, Train Loss: 1.5794, Train Acc: 0.8696, Test Loss: 1.5672, Test Acc: 0.8825
# Epoch 44/100, Train Loss: 1.5795, Train Acc: 0.8697, Test Loss: 1.5671, Test Acc: 0.8826
# Epoch 45/100, Train Loss: 1.5795, Train Acc: 0.8698, Test Loss: 1.5667, Test Acc: 0.8830
# Epoch 46/100, Train Loss: 1.5795, Train Acc: 0.8699, Test Loss: 1.5668, Test Acc: 0.8828
# Epoch 47/100, Train Loss: 1.5792, Train Acc: 0.8700, Test Loss: 1.5669, Test Acc: 0.8826
# Early stopping at epoch 47 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_forward_curriculum_5

# %%
# Plot the results
plot_metrics(mlp_sigmoid_all_train_losses, mlp_sigmoid_all_test_losses, mlp_sigmoid_all_train_accuracies, mlp_sigmoid_all_test_accuracies, epochs_per_level=[25, 21, 23, 31, 47], stage_labels=[f"Noise {nl}" for nl in noise_levels])

# %% [markdown]
# ## MLP (Softmax)

# %% [markdown]
# Defining MLP

# %%
class MLP_Softmax(nn.Module):
    def __init__(self, input_dim=784, output_dim=10):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 1000), nn.ReLU(),
            nn.Linear(1000, 500), nn.ReLU(),
            nn.Linear(500, 50), nn.ReLU(),
            nn.Linear(50, output_dim), nn.LogSoftmax(dim=-1), #nn.ReLU() nn.LogSoftmax(dim=-1)
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# Training a MLP (no curriculum)

# %%
loss_fn = nn.CrossEntropyLoss()
LEARNING_RATE = 0.03
EPOCHS = 100

# %%
mlp_softmax_model = MLP_Softmax().to(device)
optimizer = torch.optim.SGD(mlp_softmax_model.parameters(), lr=LEARNING_RATE, momentum=0.9)

# Use the new train function that also evaluates on test set
mlp_softmax_train_losses, mlp_softmax_train_accs, mlp_softmax_test_losses, mlp_softmax_test_accs = train_model(
    mlp_softmax_model, combined_train_dl, test_dl, loss_fn, optimizer, epochs=EPOCHS, save_path = "mlp_no_curriculum")

# Plot the losses and accuracies
plot_metrics(mlp_softmax_train_losses, mlp_softmax_test_losses, mlp_softmax_train_accs, mlp_softmax_test_accs)
# Out:
# Epoch 1/100, Train Loss: 1.0702, Train Acc: 0.6419, Test Loss: 0.7315, Test Acc: 0.7546
# Epoch 2/100, Train Loss: 0.6539, Train Acc: 0.7816, Test Loss: 0.6376, Test Acc: 0.7833
# Epoch 3/100, Train Loss: 0.5415, Train Acc: 0.8194, Test Loss: 0.6226, Test Acc: 0.7926
# Epoch 4/100, Train Loss: 0.4551, Train Acc: 0.8487, Test Loss: 0.6005, Test Acc: 0.8001
# Epoch 5/100, Train Loss: 0.3702, Train Acc: 0.8766, Test Loss: 0.6234, Test Acc: 0.7992
# Epoch 6/100, Train Loss: 0.2909, Train Acc: 0.9023, Test Loss: 0.6609, Test Acc: 0.7964
# Epoch 7/100, Train Loss: 0.2225, Train Acc: 0.9252, Test Loss: 0.7475, Test Acc: 0.7933
# Epoch 8/100, Train Loss: 0.1710, Train Acc: 0.9418, Test Loss: 0.8319, Test Acc: 0.7841
# Epoch 9/100, Train Loss: 0.1229, Train Acc: 0.9582, Test Loss: 0.9560, Test Acc: 0.7792
# Epoch 10/100, Train Loss: 0.0950, Train Acc: 0.9677, Test Loss: 0.9891, Test Acc: 0.7876
# Epoch 11/100, Train Loss: 0.0585, Train Acc: 0.9802, Test Loss: 1.1302, Test Acc: 0.7910
# Epoch 12/100, Train Loss: 0.0563, Train Acc: 0.9803, Test Loss: 1.2947, Test Acc: 0.7787
# Epoch 13/100, Train Loss: 0.0436, Train Acc: 0.9849, Test Loss: 1.3599, Test Acc: 0.7877
# Epoch 14/100, Train Loss: 0.0288, Train Acc: 0.9904, Test Loss: 1.3150, Test Acc: 0.7899
# Epoch 15/100, Train Loss: 0.0262, Train Acc: 0.9912, Test Loss: 1.3415, Test Acc: 0.7887
# Epoch 16/100, Train Loss: 0.0248, Train Acc: 0.9914, Test Loss: 1.4325, Test Acc: 0.7876
# Epoch 17/100, Train Loss: 0.0236, Train Acc: 0.9921, Test Loss: 1.4490, Test Acc: 0.7878
# Epoch 18/100, Train Loss: 0.0186, Train Acc: 0.9938, Test Loss: 1.5034, Test Acc: 0.7919
# Epoch 19/100, Train Loss: 0.0144, Train Acc: 0.9952, Test Loss: 1.5773, Test Acc: 0.7924
# Early stopping at epoch 19 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_no_curriculum

# %% [markdown]
# Training MLP (forward curriculum)

# %%
mlp_softmax_model_curriculum = MLP_Softmax().to(device)

# Accumulate metrics across curriculum levels
mlp_softmax_all_train_losses = []
mlp_softmax_all_test_losses = []
mlp_softmax_all_train_accuracies = []
mlp_softmax_all_test_accuracies = []

for i, noise_level in enumerate(noise_levels):
    train_dl = DataLoader(binary_flip_datasets[noise_level], batch_size=256, shuffle=True)
    optimizer = torch.optim.SGD(mlp_softmax_model_curriculum.parameters(), lr=LEARNING_RATE, momentum=0.9)

    # Use new train function
    train_losses, train_accs, test_losses, test_accs = train_model(
        mlp_softmax_model_curriculum, train_dl, test_dl, loss_fn, optimizer, epochs=EPOCHS, save_path = f"mlp_forward_curriculum_{i+1}"
    )

    # Accumulate metrics
    mlp_softmax_all_train_losses += train_losses
    mlp_softmax_all_test_losses += test_losses
    mlp_softmax_all_train_accuracies += train_accs
    mlp_softmax_all_test_accuracies += test_accs
# Out:
# Epoch 1/100, Train Loss: 0.8755, Train Acc: 0.7362, Test Loss: 1.9474, Test Acc: 0.5766
# Epoch 2/100, Train Loss: 0.1963, Train Acc: 0.9421, Test Loss: 2.2258, Test Acc: 0.5645
# Epoch 3/100, Train Loss: 0.1181, Train Acc: 0.9653, Test Loss: 2.0082, Test Acc: 0.5793
# Epoch 4/100, Train Loss: 0.0819, Train Acc: 0.9755, Test Loss: 2.3654, Test Acc: 0.5561
# Epoch 5/100, Train Loss: 0.0615, Train Acc: 0.9816, Test Loss: 2.4147, Test Acc: 0.5610
# Epoch 6/100, Train Loss: 0.0476, Train Acc: 0.9853, Test Loss: 2.9467, Test Acc: 0.5308
# Epoch 7/100, Train Loss: 0.0370, Train Acc: 0.9892, Test Loss: 2.8041, Test Acc: 0.5389
# Epoch 8/100, Train Loss: 0.0296, Train Acc: 0.9913, Test Loss: 2.9917, Test Acc: 0.5419
# Epoch 9/100, Train Loss: 0.0218, Train Acc: 0.9937, Test Loss: 2.8523, Test Acc: 0.5649
# Epoch 10/100, Train Loss: 0.0161, Train Acc: 0.9958, Test Loss: 3.6920, Test Acc: 0.5269
# Epoch 11/100, Train Loss: 0.0119, Train Acc: 0.9972, Test Loss: 3.0932, Test Acc: 0.5676
# Epoch 12/100, Train Loss: 0.0092, Train Acc: 0.9981, Test Loss: 3.6525, Test Acc: 0.5462
# Epoch 13/100, Train Loss: 0.0075, Train Acc: 0.9985, Test Loss: 3.3703, Test Acc: 0.5562
# Epoch 14/100, Train Loss: 0.0085, Train Acc: 0.9981, Test Loss: 3.4975, Test Acc: 0.5573
# Epoch 15/100, Train Loss: 0.0037, Train Acc: 0.9995, Test Loss: 4.1870, Test Acc: 0.5357
# Epoch 16/100, Train Loss: 0.0019, Train Acc: 0.9999, Test Loss: 4.0194, Test Acc: 0.5509
# Epoch 17/100, Train Loss: 0.0014, Train Acc: 0.9999, Test Loss: 4.2327, Test Acc: 0.5486
# Epoch 18/100, Train Loss: 0.0012, Train Acc: 1.0000, Test Loss: 4.3464, Test Acc: 0.5464
# Early stopping at epoch 18 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_forward_curriculum_1
# Epoch 1/100, Train Loss: 0.1637, Train Acc: 0.9471, Test Loss: 0.9067, Test Acc: 0.7190
# Epoch 2/100, Train Loss: 0.0432, Train Acc: 0.9863, Test Loss: 1.0055, Test Acc: 0.7230
# Epoch 3/100, Train Loss: 0.0144, Train Acc: 0.9964, Test Loss: 1.1903, Test Acc: 0.7170
# Epoch 4/100, Train Loss: 0.0037, Train Acc: 0.9998, Test Loss: 1.2024, Test Acc: 0.7283
# Epoch 5/100, Train Loss: 0.0013, Train Acc: 1.0000, Test Loss: 1.2718, Test Acc: 0.7290
# Epoch 6/100, Train Loss: 0.0008, Train Acc: 1.0000, Test Loss: 1.3512, Test Acc: 0.7287
# Epoch 7/100, Train Loss: 0.0006, Train Acc: 1.0000, Test Loss: 1.3811, Test Acc: 0.7289
# Epoch 8/100, Train Loss: 0.0005, Train Acc: 1.0000, Test Loss: 1.4447, Test Acc: 0.7269
# Epoch 9/100, Train Loss: 0.0004, Train Acc: 1.0000, Test Loss: 1.4540, Test Acc: 0.7278
# Epoch 10/100, Train Loss: 0.0004, Train Acc: 1.0000, Test Loss: 1.4725, Test Acc: 0.7284
# Epoch 11/100, Train Loss: 0.0003, Train Acc: 1.0000, Test Loss: 1.5045, Test Acc: 0.7276
# Epoch 12/100, Train Loss: 0.0003, Train Acc: 1.0000, Test Loss: 1.5189, Test Acc: 0.7277
# Epoch 13/100, Train Loss: 0.0003, Train Acc: 1.0000, Test Loss: 1.5225, Test Acc: 0.7287
# Epoch 14/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 1.5417, Test Acc: 0.7282
# Epoch 15/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 1.5620, Test Acc: 0.7277
# Epoch 16/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 1.5684, Test Acc: 0.7284
# Epoch 17/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 1.5911, Test Acc: 0.7273
# Epoch 18/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 1.5992, Test Acc: 0.7275
# Epoch 19/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 1.6011, Test Acc: 0.7280
# Epoch 20/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 1.6160, Test Acc: 0.7278
# Early stopping at epoch 20 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_forward_curriculum_2
# Epoch 1/100, Train Loss: 0.3621, Train Acc: 0.8829, Test Loss: 0.7060, Test Acc: 0.7726
# Epoch 2/100, Train Loss: 0.1507, Train Acc: 0.9494, Test Loss: 0.6819, Test Acc: 0.7873
# Epoch 3/100, Train Loss: 0.0594, Train Acc: 0.9820, Test Loss: 0.7868, Test Acc: 0.7878
# Epoch 4/100, Train Loss: 0.0189, Train Acc: 0.9959, Test Loss: 0.8426, Test Acc: 0.7929
# Epoch 5/100, Train Loss: 0.0046, Train Acc: 0.9997, Test Loss: 0.8868, Test Acc: 0.8016
# Epoch 6/100, Train Loss: 0.0015, Train Acc: 1.0000, Test Loss: 0.9386, Test Acc: 0.8047
# Epoch 7/100, Train Loss: 0.0009, Train Acc: 1.0000, Test Loss: 0.9832, Test Acc: 0.8043
# Epoch 8/100, Train Loss: 0.0006, Train Acc: 1.0000, Test Loss: 1.0109, Test Acc: 0.8043
# Epoch 9/100, Train Loss: 0.0005, Train Acc: 1.0000, Test Loss: 1.0395, Test Acc: 0.8038
# Epoch 10/100, Train Loss: 0.0004, Train Acc: 1.0000, Test Loss: 1.0573, Test Acc: 0.8038
# Epoch 11/100, Train Loss: 0.0003, Train Acc: 1.0000, Test Loss: 1.0675, Test Acc: 0.8043
# Epoch 12/100, Train Loss: 0.0003, Train Acc: 1.0000, Test Loss: 1.0840, Test Acc: 0.8043
# Epoch 13/100, Train Loss: 0.0003, Train Acc: 1.0000, Test Loss: 1.0959, Test Acc: 0.8041
# Epoch 14/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 1.1057, Test Acc: 0.8040
# Epoch 15/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 1.1166, Test Acc: 0.8039
# Epoch 16/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 1.1267, Test Acc: 0.8040
# Epoch 17/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 1.1334, Test Acc: 0.8040
# Epoch 18/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 1.1437, Test Acc: 0.8038
# Epoch 19/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 1.1495, Test Acc: 0.8040
# Epoch 20/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.1573, Test Acc: 0.8039
# Epoch 21/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.1605, Test Acc: 0.8041
# Early stopping at epoch 21 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_forward_curriculum_3
# Epoch 1/100, Train Loss: 0.8521, Train Acc: 0.7201, Test Loss: 0.6337, Test Acc: 0.7965
# Epoch 2/100, Train Loss: 0.5502, Train Acc: 0.8156, Test Loss: 0.5800, Test Acc: 0.8230
# Epoch 3/100, Train Loss: 0.4015, Train Acc: 0.8650, Test Loss: 0.5893, Test Acc: 0.8309
# Epoch 4/100, Train Loss: 0.2719, Train Acc: 0.9103, Test Loss: 0.6629, Test Acc: 0.8265
# Epoch 5/100, Train Loss: 0.1817, Train Acc: 0.9392, Test Loss: 0.7330, Test Acc: 0.8330
# Epoch 6/100, Train Loss: 0.1245, Train Acc: 0.9580, Test Loss: 0.8254, Test Acc: 0.8344
# Epoch 7/100, Train Loss: 0.0812, Train Acc: 0.9731, Test Loss: 0.8970, Test Acc: 0.8364
# Epoch 8/100, Train Loss: 0.0555, Train Acc: 0.9814, Test Loss: 0.9537, Test Acc: 0.8367
# Epoch 9/100, Train Loss: 0.0425, Train Acc: 0.9855, Test Loss: 1.0326, Test Acc: 0.8375
# Epoch 10/100, Train Loss: 0.0424, Train Acc: 0.9856, Test Loss: 1.0481, Test Acc: 0.8341
# Epoch 11/100, Train Loss: 0.0518, Train Acc: 0.9823, Test Loss: 1.0737, Test Acc: 0.8359
# Epoch 12/100, Train Loss: 0.0366, Train Acc: 0.9877, Test Loss: 1.1255, Test Acc: 0.8369
# Epoch 13/100, Train Loss: 0.0206, Train Acc: 0.9933, Test Loss: 1.1892, Test Acc: 0.8404
# Epoch 14/100, Train Loss: 0.0093, Train Acc: 0.9973, Test Loss: 1.1937, Test Acc: 0.8414
# Epoch 15/100, Train Loss: 0.0029, Train Acc: 0.9996, Test Loss: 1.2670, Test Acc: 0.8439
# Epoch 16/100, Train Loss: 0.0005, Train Acc: 1.0000, Test Loss: 1.2876, Test Acc: 0.8441
# Epoch 17/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 1.3094, Test Acc: 0.8443
# Epoch 18/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.3272, Test Acc: 0.8443
# Epoch 19/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.3418, Test Acc: 0.8444
# Epoch 20/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.3537, Test Acc: 0.8446
# Epoch 21/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.3640, Test Acc: 0.8447
# Epoch 22/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.3733, Test Acc: 0.8446
# Epoch 23/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.3808, Test Acc: 0.8448
# Epoch 24/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.3886, Test Acc: 0.8448
# Epoch 25/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.3954, Test Acc: 0.8448
# Epoch 26/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.4014, Test Acc: 0.8448
# Epoch 27/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.4069, Test Acc: 0.8449
# Epoch 28/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.4127, Test Acc: 0.8448
# Epoch 29/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.4177, Test Acc: 0.8449
# Epoch 30/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.4223, Test Acc: 0.8449
# Epoch 31/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.4268, Test Acc: 0.8449
# Epoch 32/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 1.4311, Test Acc: 0.8449
# Epoch 33/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4352, Test Acc: 0.8449
# Epoch 34/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4392, Test Acc: 0.8450
# Epoch 35/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4427, Test Acc: 0.8449
# Epoch 36/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4464, Test Acc: 0.8450
# Epoch 37/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4499, Test Acc: 0.8450
# Epoch 38/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4532, Test Acc: 0.8450
# Epoch 39/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4565, Test Acc: 0.8450
# Epoch 40/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4598, Test Acc: 0.8450
# Epoch 41/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4628, Test Acc: 0.8450
# Epoch 42/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4657, Test Acc: 0.8450
# Epoch 43/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4684, Test Acc: 0.8450
# Epoch 44/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4711, Test Acc: 0.8451
# Epoch 45/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4737, Test Acc: 0.8451
# Epoch 46/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4765, Test Acc: 0.8450
# Epoch 47/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4788, Test Acc: 0.8450
# Epoch 48/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4813, Test Acc: 0.8450
# Epoch 49/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4839, Test Acc: 0.8450
# Epoch 50/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4862, Test Acc: 0.8450
# Epoch 51/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4885, Test Acc: 0.8450
# Epoch 52/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4906, Test Acc: 0.8451
# Epoch 53/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4928, Test Acc: 0.8451
# Epoch 54/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4951, Test Acc: 0.8451
# Epoch 55/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4971, Test Acc: 0.8451
# Epoch 56/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.4992, Test Acc: 0.8451
# Epoch 57/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5012, Test Acc: 0.8451
# Epoch 58/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5031, Test Acc: 0.8451
# Epoch 59/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5052, Test Acc: 0.8451
# Epoch 60/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5071, Test Acc: 0.8451
# Epoch 61/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5090, Test Acc: 0.8451
# Epoch 62/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5108, Test Acc: 0.8451
# Epoch 63/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5127, Test Acc: 0.8451
# Epoch 64/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5144, Test Acc: 0.8450
# Epoch 65/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5162, Test Acc: 0.8451
# Epoch 66/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5178, Test Acc: 0.8451
# Epoch 67/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5195, Test Acc: 0.8451
# Epoch 68/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5212, Test Acc: 0.8452
# Epoch 69/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5229, Test Acc: 0.8452
# Epoch 70/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5244, Test Acc: 0.8452
# Epoch 71/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5262, Test Acc: 0.8452
# Epoch 72/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5276, Test Acc: 0.8452
# Epoch 73/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5292, Test Acc: 0.8452
# Epoch 74/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5307, Test Acc: 0.8453
# Epoch 75/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5323, Test Acc: 0.8452
# Epoch 76/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5337, Test Acc: 0.8452
# Epoch 77/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5352, Test Acc: 0.8453
# Epoch 78/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5366, Test Acc: 0.8452
# Epoch 79/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5381, Test Acc: 0.8452
# Epoch 80/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5394, Test Acc: 0.8452
# Epoch 81/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5409, Test Acc: 0.8453
# Epoch 82/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5422, Test Acc: 0.8453
# Epoch 83/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5435, Test Acc: 0.8452
# Epoch 84/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5448, Test Acc: 0.8452
# Epoch 85/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5462, Test Acc: 0.8452
# Epoch 86/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5475, Test Acc: 0.8452
# Epoch 87/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5488, Test Acc: 0.8452
# Epoch 88/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5501, Test Acc: 0.8452
# Epoch 89/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5513, Test Acc: 0.8452
# Epoch 90/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5526, Test Acc: 0.8452
# Epoch 91/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5537, Test Acc: 0.8453
# Epoch 92/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5550, Test Acc: 0.8452
# Epoch 93/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5563, Test Acc: 0.8453
# Epoch 94/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5574, Test Acc: 0.8452
# Epoch 95/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5586, Test Acc: 0.8452
# Epoch 96/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 1.5598, Test Acc: 0.8452
# Early stopping at epoch 96 (no improvement in test accuracy for 15 epochs)
# Last model saved to mlp_forward_curriculum_4
# Epoch 1/100, Train Loss: 2.0578, Train Acc: 0.2897, Test Loss: 0.7486, Test Acc: 0.7640
# Epoch 2/100, Train Loss: 1.6377, Train Acc: 0.4342, Test Loss: 0.7083, Test Acc: 0.7720
# Epoch 3/100, Train Loss: 1.5538, Train Acc: 0.4635, Test Loss: 0.6727, Test Acc: 0.7883
# Epoch 4/100, Train Loss: 1.4712, Train Acc: 0.4942, Test Loss: 0.6403, Test Acc: 0.7975
# Epoch 5/100, Train Loss: 1.3928, Train Acc: 0.5210, Test Loss: 0.6475, Test Acc: 0.7995
# Epoch 6/100, Train Loss: 1.3216, Train Acc: 0.5457, Test Loss: 0.6312, Test Acc: 0.8116
# Epoch 7/100, Train Loss: 1.2535, Train Acc: 0.5689, Test Loss: 0.6322, Test Acc: 0.8130
# Epoch 8/100, Train Loss: 1.1655, Train Acc: 0.6018, Test Loss: 0.6673, Test Acc: 0.8102
# Epoch 9/100, Train Loss: 1.1051, Train Acc: 0.6190, Test Loss: 0.6756, Test Acc: 0.8150
# Epoch 10/100, Train Loss: 1.0277, Train Acc: 0.6447, Test Loss: 0.7224, Test Acc: 0.8118
# Epoch 11/100, Train Loss: 0.9544, Train Acc: 0.6693, Test Loss: 0.6951, Test Acc: 0.8290
# Epoch 12/100, Train Loss: 0.8753, Train Acc: 0.6956, Test Loss: 0.7792, Test Acc: 0.8140
# Epoch 13/100, Train Loss: 0.8215, Train Acc: 0.7149, Test Loss: 0.8071, Test Acc: 0.8231
# Epoch 14/100, Train Loss: 0.7451, Train Acc: 0.7419, Test Loss: 0.7730, Test Acc: 0.8397
# Epoch 15/100, Train Loss: 0.6847, Train Acc: 0.7618, Test Loss: 0.7970, Test Acc: 0.8346
# Epoch 16/100, Train Loss: 0.6055, Train Acc: 0.7872, Test Loss: 0.8863, Test Acc: 0.8387
# Epoch 17/100, Train Loss: 0.5250, Train Acc: 0.8159, Test Loss: 0.9370, Test Acc: 0.8396
# Epoch 18/100, Train Loss: 0.4814, Train Acc: 0.8309, Test Loss: 0.9323, Test Acc: 0.8472
# Epoch 19/100, Train Loss: 0.4079, Train Acc: 0.8571, Test Loss: 1.0530, Test Acc: 0.8405
# Epoch 20/100, Train Loss: 0.3762, Train Acc: 0.8656, Test Loss: 1.1385, Test Acc: 0.8401
# Epoch 21/100, Train Loss: 0.3222, Train Acc: 0.8877, Test Loss: 1.1822, Test Acc: 0.8441
# Epoch 22/100, Train Loss: 0.2975, Train Acc: 0.8951, Test Loss: 1.2033, Test Acc: 0.8455
# Epoch 23/100, Train Loss: 0.2862, Train Acc: 0.8995, Test Loss: 1.1965, Test Acc: 0.8479
# Epoch 24/100, Train Loss: 0.2252, Train Acc: 0.9208, Test Loss: 1.4086, Test Acc: 0.8470
# Epoch 25/100, Train Loss: 0.2114, Train Acc: 0.9255, Test Loss: 1.3502, Test Acc: 0.8562
# Epoch 26/100, Train Loss: 0.2092, Train Acc: 0.9262, Test Loss: 1.4916, Test Acc: 0.8415
# Epoch 27/100, Train Loss: 0.1894, Train Acc: 0.9334, Test Loss: 1.5184, Test Acc: 0.8505
# Epoch 28/100, Train Loss: 0.1874, Train Acc: 0.9352, Test Loss: 1.6432, Test Acc: 0.8452
# Epoch 29/100, Train Loss: 0.1408, Train Acc: 0.9515, Test Loss: 1.6725, Test Acc: 0.8476
# Epoch 30/100, Train Loss: 0.1496, Train Acc: 0.9481, Test Loss: 1.6479, Test Acc: 0.8505
# Epoch 31/100, Train Loss: 0.1288, Train Acc: 0.9553, Test Loss: 1.6862, Test Acc: 0.8517
# Epoch 32/100, Train Loss: 0.1248, Train Acc: 0.9568, Test Loss: 1.7475, Test Acc: 0.8555
# Epoch 33/100, Train Loss: 0.1039, Train Acc: 0.9643, Test Loss: 2.0044, Test Acc: 0.8450
# Epoch 34/100, Train Loss: 0.0961, Train Acc: 0.9668, Test Loss: 1.9136, Test Acc: 0.8514
# Epoch 35/100, Train Loss: 0.0725, Train Acc: 0.9756, Test Loss: 1.9484, Test Acc: 0.8564
# Epoch 36/100, Train Loss: 0.0617, Train Acc: 0.9790, Test Loss: 2.0142, Test Acc: 0.8529
# Epoch 37/100, Train Loss: 0.0653, Train Acc: 0.9771, Test Loss: 2.0106, Test Acc: 0.8575
# Epoch 38/100, Train Loss: 0.0735, Train Acc: 0.9748, Test Loss: 2.0272, Test Acc: 0.8515
# Epoch 39/100, Train Loss: 0.0855, Train Acc: 0.9703, Test Loss: 2.0802, Test Acc: 0.8516
# Epoch 40/100, Train Loss: 0.1179, Train Acc: 0.9605, Test Loss: 1.9568, Test Acc: 0.8518
# Epoch 41/100, Train Loss: 0.0847, Train Acc: 0.9707, Test Loss: 2.0899, Test Acc: 0.8543
# Epoch 42/100, Train Loss: 0.0678, Train Acc: 0.9757, Test Loss: 2.0976, Test Acc: 0.8560
# Epoch 43/100, Train Loss: 0.0456, Train Acc: 0.9847, Test Loss: 2.1861, Test Acc: 0.8553
# Epoch 44/100, Train Loss: 0.0552, Train Acc: 0.9815, Test Loss: 2.1775, Test Acc: 0.8559
# Epoch 45/100, Train Loss: 0.0457, Train Acc: 0.9838, Test Loss: 2.1541, Test Acc: 0.8593
# Epoch 46/100, Train Loss: 0.0739, Train Acc: 0.9751, Test Loss: 2.2175, Test Acc: 0.8511
# Epoch 47/100, Train Loss: 0.0660, Train Acc: 0.9777, Test Loss: 2.1271, Test Acc: 0.8570
# Epoch 48/100, Train Loss: 0.0487, Train Acc: 0.9832, Test Loss: 2.3240, Test Acc: 0.8540
# Epoch 49/100, Train Loss: 0.0435, Train Acc: 0.9849, Test Loss: 2.3109, Test Acc: 0.8570
# Epoch 50/100, Train Loss: 0.0524, Train Acc: 0.9821, Test Loss: 2.3989, Test Acc: 0.8547
# Epoch 51/100, Train Loss: 0.0348, Train Acc: 0.9884, Test Loss: 2.3512, Test Acc: 0.8553
# Epoch 52/100, Train Loss: 0.0312, Train Acc: 0.9896, Test Loss: 2.4335, Test Acc: 0.8545
# Epoch 53/100, Train Loss: 0.0198, Train Acc: 0.9936, Test Loss: 2.4835, Test Acc: 0.8570
# Epoch 54/100, Train Loss: 0.0205, Train Acc: 0.9929, Test Loss: 2.6008, Test Acc: 0.8551
# Epoch 55/100, Train Loss: 0.0055, Train Acc: 0.9986, Test Loss: 2.6041, Test Acc: 0.8600
# Epoch 56/100, Train Loss: 0.0011, Train Acc: 0.9999, Test Loss: 2.6060, Test Acc: 0.8610
# Epoch 57/100, Train Loss: 0.0003, Train Acc: 1.0000, Test Loss: 2.6411, Test Acc: 0.8611
# Epoch 58/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 2.6611, Test Acc: 0.8611
# Epoch 59/100, Train Loss: 0.0002, Train Acc: 1.0000, Test Loss: 2.6740, Test Acc: 0.8613
# Epoch 60/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.6870, Test Acc: 0.8613
# Epoch 61/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.6972, Test Acc: 0.8614
# Epoch 62/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.7085, Test Acc: 0.8615
# Epoch 63/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.7174, Test Acc: 0.8616
# Epoch 64/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.7275, Test Acc: 0.8616
# Epoch 65/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.7363, Test Acc: 0.8616
# Epoch 66/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.7423, Test Acc: 0.8618
# Epoch 67/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.7505, Test Acc: 0.8618
# Epoch 68/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.7585, Test Acc: 0.8618
# Epoch 69/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.7650, Test Acc: 0.8619
# Epoch 70/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.7716, Test Acc: 0.8619
# Epoch 71/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.7783, Test Acc: 0.8620
# Epoch 72/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.7840, Test Acc: 0.8620
# Epoch 73/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.7908, Test Acc: 0.8620
# Epoch 74/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.7958, Test Acc: 0.8620
# Epoch 75/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.8004, Test Acc: 0.8620
# Epoch 76/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.8056, Test Acc: 0.8620
# Epoch 77/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.8122, Test Acc: 0.8620
# Epoch 78/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.8168, Test Acc: 0.8620
# Epoch 79/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.8215, Test Acc: 0.8621
# Epoch 80/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.8272, Test Acc: 0.8620
# Epoch 81/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.8314, Test Acc: 0.8621
# Epoch 82/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.8354, Test Acc: 0.8621
# Epoch 83/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.8398, Test Acc: 0.8621
# Epoch 84/100, Train Loss: 0.0001, Train Acc: 1.0000, Test Loss: 2.8437, Test Acc: 0.8621
# Epoch 85/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8480, Test Acc: 0.8622
# Epoch 86/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8520, Test Acc: 0.8622
# Epoch 87/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8564, Test Acc: 0.8622
# Epoch 88/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8600, Test Acc: 0.8623
# Epoch 89/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8640, Test Acc: 0.8623
# Epoch 90/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8676, Test Acc: 0.8623
# Epoch 91/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8716, Test Acc: 0.8622
# Epoch 92/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8755, Test Acc: 0.8623
# Epoch 93/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8785, Test Acc: 0.8623
# Epoch 94/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8818, Test Acc: 0.8623
# Epoch 95/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8852, Test Acc: 0.8623
# Epoch 96/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8887, Test Acc: 0.8623
# Epoch 97/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8924, Test Acc: 0.8623
# Epoch 98/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8952, Test Acc: 0.8623
# Epoch 99/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.8987, Test Acc: 0.8623
# Epoch 100/100, Train Loss: 0.0000, Train Acc: 1.0000, Test Loss: 2.9014, Test Acc: 0.8623
# Last model saved to mlp_forward_curriculum_5

# %%
# Plot the results
plot_metrics(mlp_softmax_all_train_losses, mlp_softmax_all_test_losses, mlp_softmax_all_train_accuracies, mlp_softmax_all_test_accuracies, epochs_per_level=[18, 20, 21, 96, 100], stage_labels=[f"Noise {nl}" for nl in noise_levels])
